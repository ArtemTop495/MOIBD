# %%
import pandas as pd
import string
import re
import nltk
import pymorphy3

from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem.snowball import SnowballStemmer

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\artembruh\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\artembruh\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# True

# %%
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\artembruh\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt_tab.zip.
# True

# %%
df = pd.read_csv("pdf_and_games_and_json.csv")

# %%
df.head()
# Out:
#    Unnamed: 0                                      title  \
# 0           0                           Counter-Strike 2
# 1           1                Clair Obscur: Expedition 33
# 2           2                        DOOM: The Dark Ages
# 3           3                                 Schedule I
# 4           4  The Elder Scrolls IV: Oblivion Remastered
#
#                                          description          date  \
# 0  Об этой игре Более двух десятилетий Counter-St...  21 Aug, 2012
# 1  Об этой игре Раз в год Художница просыпается и...  24 Apr, 2025
# 2  Об этой игре СТАНЬТЕ ПАЛАЧОМ В СРЕДНЕВЕКОВОЙ В...  14 May, 2025
# 3  Об этой игре Schedule I drugs, substances, or ...  24 Mar, 2025
# 4  Об этой игре The Elder Scrolls IV: Oblivion™ R...  22 Apr, 2025
#
#                                                 tags   rating
# 0  Шутер от первого лица, Шутер, Для нескольких и...   9 / 10
# 1  Пошаговые сражения, Глубокий сюжет, Фэнтези, И...   9 / 10
# 2  Экшен, Шутер от первого лица, Демоны, Тёмное ф...   9 / 10
# 3  Симулятор, Кооператив, Криминал, Для нескольки...  10 / 10
# 4  Ролевая игра, Открытый мир, Фэнтези, Для одног...   9 / 10

# %% [markdown]
# __title__ - название статьи/игры/файла
#
# __description__ - описание статьи/игры/файла
#
# __date_publish__ - дата выхода/публикации
#
# __tags__ - тэги статьи/игры/файла
#
# __rating__ - рейтинг статьи/игры/файла

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 870 entries, 0 to 869
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   870 non-null    int64
#  1   title        870 non-null    object
#  2   description  870 non-null    object
#  3   date         870 non-null    object
#  4   tags         61 non-null     object
#  5   rating       870 non-null    object
# dtypes: int64(1), object(5)
# memory usage: 40.9+ KB

# %% [markdown]
# ## 2. Предварительная обработка данных

# %% [markdown]
# 1. Перевод всех букв в тексте в нижний регистр
# 2. Удаление знаков препинания
# 3. Токенизация по словам
# 4. Удаление стоп слов
# 5. Стемминг (приведение слов к нормальной форме)
# 6. Лемматизация

# %%
def remove_punctuation(text): 
    return "".join([ch if ch not in string.punctuation else ' ' for ch in text])

def remove_numbers(text): 
    return ''.join([i if not i.isdigit() else ' ' for i in text])

def remove_multiple_spaces(text): 
    return re.sub(r'\s+', ' ', text, flags=re.I)

st = '❯\xa0—«»'
def remove_othersymbol(text):
    return ''.join([ch if ch not in st else ' ' for ch in text])

# %%
df['prep_text'] = [remove_multiple_spaces(remove_numbers(remove_othersymbol(remove_punctuation(text.lower())))) for text in df['description']]

# %%
df.head()
# Out:
#    Unnamed: 0                                      title  \
# 0           0                           Counter-Strike 2
# 1           1                Clair Obscur: Expedition 33
# 2           2                        DOOM: The Dark Ages
# 3           3                                 Schedule I
# 4           4  The Elder Scrolls IV: Oblivion Remastered
#
#                                          description          date  \
# 0  Об этой игре Более двух десятилетий Counter-St...  21 Aug, 2012
# 1  Об этой игре Раз в год Художница просыпается и...  24 Apr, 2025
# 2  Об этой игре СТАНЬТЕ ПАЛАЧОМ В СРЕДНЕВЕКОВОЙ В...  14 May, 2025
# 3  Об этой игре Schedule I drugs, substances, or ...  24 Mar, 2025
# 4  Об этой игре The Elder Scrolls IV: Oblivion™ R...  22 Apr, 2025
#
#                                                 tags   rating  \
# 0  Шутер от первого лица, Шутер, Для нескольких и...   9 / 10
# 1  Пошаговые сражения, Глубокий сюжет, Фэнтези, И...   9 / 10
# 2  Экшен, Шутер от первого лица, Демоны, Тёмное ф...   9 / 10
# 3  Симулятор, Кооператив, Криминал, Для нескольки...  10 / 10
# 4  Ролевая игра, Открытый мир, Фэнтези, Для одног...   9 / 10
#
#                                            prep_text
# 0  об этой игре более двух десятилетий counter st...
# 1  об этой игре раз в год художница просыпается и...
# 2  об этой игре станьте палачом в средневековой в...
# 3  об этой игре schedule i drugs substances or ch...
# 4  об этой игре the elder scrolls iv oblivion™ re...

# %%
df['description'][0]
# Out:
# 'Об этой игре Более двух десятилетий Counter-Strike служит примером первоклассной соревновательной игры, путь развития которой определяют миллионы игроков со всего мира. Теперь пришло время нового этапа — Counter-Strike 2.Counter-Strike 2 — это бесплатное улучшение для CS:GO, которое знаменует собой крупнейший технологический скачок в истории серии. Оно разработано на движке Source 2 и модернизирует игру благодаря реалистичному и физически корректному рендерингу, организации сети по последнему слову технологий и улучшенным инструментам для мастерской сообщества.Кроме представленного в 1999 году классического игрового процесса, завязанного на достижении цели, Counter-Strike 2 включает:новые рейтинги CS и обновлённый премьер-режим;глобальные и региональные таблицы лидеров;улучшенные и воссозданные с нуля карты;принципиально новый динамический дым от гранат;игровой процесс, не зависящий от тикрейта;переосмысленные визуальные эффекты и звуки;все предметы инвентаря из CS:GO.'

# %%
df['prep_text'][0]
# Out:
# 'об этой игре более двух десятилетий counter strike служит примером первоклассной соревновательной игры путь развития которой определяют миллионы игроков со всего мира теперь пришло время нового этапа counter strike counter strike это бесплатное улучшение для cs go которое знаменует собой крупнейший технологический скачок в истории серии оно разработано на движке source и модернизирует игру благодаря реалистичному и физически корректному рендерингу организации сети по последнему слову технологий и улучшенным инструментам для мастерской сообщества кроме представленного в году классического игрового процесса завязанного на достижении цели counter strike включает новые рейтинги cs и обновлённый премьер режим глобальные и региональные таблицы лидеров улучшенные и воссозданные с нуля карты принципиально новый динамический дым от гранат игровой процесс не зависящий от тикрейта переосмысленные визуальные эффекты и звуки все предметы инвентаря из cs go '

# %%
russian_stopwords = stopwords.words("russian")
russian_stopwords.extend(['т.д.', 'т', 'д', 'это','который','с','своём','всем','наш', 'свой']) 
russian_stopwords
# Out:
# ['и',
#  'в',
#  'во',
#  'не',
#  'что',
#  'он',
#  'на',
#  'я',
#  'с',
#  'со',
#  'как',
#  'а',
#  'то',
#  'все',
#  'она',
#  'так',
#  'его',
#  'но',
#  'да',
#  'ты',
#  'к',
#  'у',
#  'же',
#  'вы',
#  'за',
#  'бы',
#  'по',
#  'только',
#  'ее',
#  'мне',
#  'было',
#  'вот',
#  'от',
#  'меня',
#  'еще',
#  'нет',
#  'о',
#  'из',
#  'ему',
#  'теперь',
#  'когда',
#  'даже',
#  'ну',
#  'вдруг',
#  'ли',
#  'если',
#  'уже',
#  'или',
#  'ни',
#  'быть',
#  'был',
#  'него',
#  'до',
#  'вас',
#  'нибудь',
#  'опять',
#  'уж',
#  'вам',
#  'ведь',
#  'там',
#  'потом',
#  'себя',
#  'ничего',
#  'ей',
#  'может',
#  'они',
#  'тут',
#  'где',
#  'есть',
#  'надо',
#  'ней',
#  'для',
#  'мы',
#  'тебя',
#  'их',
#  'чем',
#  'была',
#  'сам',
#  'чтоб',
#  'без',
#  'будто',
#  'чего',
#  'раз',
#  'тоже',
#  'себе',
#  'под',
#  'будет',
#  'ж',
#  'тогда',
#  'кто',
#  'этот',
#  'того',
#  'потому',
#  'этого',
#  'какой',
#  'совсем',
#  'ним',
#  'здесь',
#  'этом',
#  'один',
#  'почти',
#  'мой',
#  'тем',
#  'чтобы',
#  'нее',
#  'сейчас',
#  'были',
#  'куда',
#  'зачем',
#  'всех',
#  'никогда',
#  'можно',
#  'при',
#  'наконец',
#  'два',
#  'об',
#  'другой',
#  'хоть',
#  'после',
#  'над',
#  'больше',
#  'тот',
#  'через',
#  'эти',
#  'нас',
#  'про',
#  'всего',
#  'них',
#  'какая',
#  'много',
#  'разве',
#  'три',
#  'эту',
#  'моя',
#  'впрочем',
#  'хорошо',
#  'свою',
#  'этой',
#  'перед',
#  'иногда',
#  'лучше',
#  'чуть',
#  'том',
#  'нельзя',
#  'такой',
#  'им',
#  'более',
#  'всегда',
#  'конечно',
#  'всю',
#  'между',
#  'т.д.',
#  'т',
#  'д',
#  'это',
#  'который',
#  'с',
#  'своём',
#  'всем',
#  'наш',
#  'свой']

# %%
def tokenize(text):
    t = word_tokenize(text)
    tokens = [token for token in t if token not in russian_stopwords]
    text = " ".join(tokens)
    return text

# %%
df['tokenize_text'] = [tokenize(text) for text in df['prep_text']]

# %%
df.head()
# Out:
#    Unnamed: 0                                      title  \
# 0           0                           Counter-Strike 2
# 1           1                Clair Obscur: Expedition 33
# 2           2                        DOOM: The Dark Ages
# 3           3                                 Schedule I
# 4           4  The Elder Scrolls IV: Oblivion Remastered
#
#                                          description          date  \
# 0  Об этой игре Более двух десятилетий Counter-St...  21 Aug, 2012
# 1  Об этой игре Раз в год Художница просыпается и...  24 Apr, 2025
# 2  Об этой игре СТАНЬТЕ ПАЛАЧОМ В СРЕДНЕВЕКОВОЙ В...  14 May, 2025
# 3  Об этой игре Schedule I drugs, substances, or ...  24 Mar, 2025
# 4  Об этой игре The Elder Scrolls IV: Oblivion™ R...  22 Apr, 2025
#
#                                                 tags   rating  \
# 0  Шутер от первого лица, Шутер, Для нескольких и...   9 / 10
# 1  Пошаговые сражения, Глубокий сюжет, Фэнтези, И...   9 / 10
# 2  Экшен, Шутер от первого лица, Демоны, Тёмное ф...   9 / 10
# 3  Симулятор, Кооператив, Криминал, Для нескольки...  10 / 10
# 4  Ролевая игра, Открытый мир, Фэнтези, Для одног...   9 / 10
#
#                                            prep_text  \
# 0  об этой игре более двух десятилетий counter st...
# 1  об этой игре раз в год художница просыпается и...
# 2  об этой игре станьте палачом в средневековой в...
# 3  об этой игре schedule i drugs substances or ch...
# 4  об этой игре the elder scrolls iv oblivion™ re...
#
#                                        tokenize_text
# 0  игре двух десятилетий counter strike служит пр...
# 1  игре год художница просыпается рисует монолите...
# 2  игре станьте палачом средневековой войне адомd...
# 3  игре schedule i drugs substances or chemicals ...
# 4  игре the elder scrolls iv oblivion™ remastered...

# %%
df['tokenize_text'][0]
# Out:
# 'игре двух десятилетий counter strike служит примером первоклассной соревновательной игры путь развития которой определяют миллионы игроков мира пришло время нового этапа counter strike counter strike бесплатное улучшение cs go которое знаменует собой крупнейший технологический скачок истории серии оно разработано движке source модернизирует игру благодаря реалистичному физически корректному рендерингу организации сети последнему слову технологий улучшенным инструментам мастерской сообщества кроме представленного году классического игрового процесса завязанного достижении цели counter strike включает новые рейтинги cs обновлённый премьер режим глобальные региональные таблицы лидеров улучшенные воссозданные нуля карты принципиально новый динамический дым гранат игровой процесс зависящий тикрейта переосмысленные визуальные эффекты звуки предметы инвентаря cs go'

# %%
stemmer = SnowballStemmer("russian")

stem_list = []
for text in (df['tokenize_text']):
    try:
        tokens = word_tokenize(text)
        res = list()
        for word in tokens:
            p = stemmer.stem(word)
            res.append(p)
        text = " ".join(res)
        stem_list.append(text)
    except Exception as e:
        print(e)
        
df['text_stem'] = stem_list

# %%
df.head()
# Out:
#    Unnamed: 0                                      title  \
# 0           0                           Counter-Strike 2
# 1           1                Clair Obscur: Expedition 33
# 2           2                        DOOM: The Dark Ages
# 3           3                                 Schedule I
# 4           4  The Elder Scrolls IV: Oblivion Remastered
#
#                                          description          date  \
# 0  Об этой игре Более двух десятилетий Counter-St...  21 Aug, 2012
# 1  Об этой игре Раз в год Художница просыпается и...  24 Apr, 2025
# 2  Об этой игре СТАНЬТЕ ПАЛАЧОМ В СРЕДНЕВЕКОВОЙ В...  14 May, 2025
# 3  Об этой игре Schedule I drugs, substances, or ...  24 Mar, 2025
# 4  Об этой игре The Elder Scrolls IV: Oblivion™ R...  22 Apr, 2025
#
#                                                 tags   rating  \
# 0  Шутер от первого лица, Шутер, Для нескольких и...   9 / 10
# 1  Пошаговые сражения, Глубокий сюжет, Фэнтези, И...   9 / 10
# 2  Экшен, Шутер от первого лица, Демоны, Тёмное ф...   9 / 10
# 3  Симулятор, Кооператив, Криминал, Для нескольки...  10 / 10
# 4  Ролевая игра, Открытый мир, Фэнтези, Для одног...   9 / 10
#
#                                            prep_text  \
# 0  об этой игре более двух десятилетий counter st...
# 1  об этой игре раз в год художница просыпается и...
# 2  об этой игре станьте палачом в средневековой в...
# 3  об этой игре schedule i drugs substances or ch...
# 4  об этой игре the elder scrolls iv oblivion™ re...
#
#                                        tokenize_text  \
# 0  игре двух десятилетий counter strike служит пр...
# 1  игре год художница просыпается рисует монолите...
# 2  игре станьте палачом средневековой войне адомd...
# 3  игре schedule i drugs substances or chemicals ...
# 4  игре the elder scrolls iv oblivion™ remastered...
#
#                                            text_stem
# 0  игр двух десятилет counter strike служ пример ...
# 1  игр год художниц просыпа рис монол вывод сво п...
# 2  игр станьт палач средневеков войн адомдо the d...
# 3  игр schedule i drugs substances or chemicals a...
# 4  игр the elder scrolls iv обливион™ remastered ...

# %%
df['text_stem'][0]
# Out:
# 'игр двух десятилет counter strike служ пример первоклассн соревновательн игр пут развит котор определя миллион игрок мир пришл врем нов этап counter strike counter strike бесплатн улучшен cs go котор знамен соб крупн технологическ скачок истор сер он разработа движк source модернизир игр благодар реалистичн физическ корректн рендеринг организац сет последн слов технолог улучшен инструмент мастерск сообществ кром представлен год классическ игров процесс завяза достижен цел counter strike включа нов рейтинг cs обновлен премьер реж глобальн региональн таблиц лидер улучшен воссозда нул карт принципиальн нов динамическ дым гранат игров процесс завися тикрейт переосмыслен визуальн эффект звук предмет инвентар cs go'

# %%
morph = pymorphy3.MorphAnalyzer(lang='ru')

# %%
# %%time
lemm_texts_list = []
for text in (df['tokenize_text']):
    try:
        tokens = word_tokenize(text)
        res = list()
        for word in tokens:
            p = morph.parse(word)[0]
            res.append(p.normal_form)
        text = " ".join(res)
        lemm_texts_list.append(text)
    except Exception as e:
        print(e)
    
df['text_lemm'] = lemm_texts_list
# Out:
# CPU times: total: 1min 56s
# Wall time: 1min 58s

# %%
df.head()
# Out:
#    Unnamed: 0                                      title  \
# 0           0                           Counter-Strike 2
# 1           1                Clair Obscur: Expedition 33
# 2           2                        DOOM: The Dark Ages
# 3           3                                 Schedule I
# 4           4  The Elder Scrolls IV: Oblivion Remastered
#
#                                          description          date  \
# 0  Об этой игре Более двух десятилетий Counter-St...  21 Aug, 2012
# 1  Об этой игре Раз в год Художница просыпается и...  24 Apr, 2025
# 2  Об этой игре СТАНЬТЕ ПАЛАЧОМ В СРЕДНЕВЕКОВОЙ В...  14 May, 2025
# 3  Об этой игре Schedule I drugs, substances, or ...  24 Mar, 2025
# 4  Об этой игре The Elder Scrolls IV: Oblivion™ R...  22 Apr, 2025
#
#                                                 tags   rating  \
# 0  Шутер от первого лица, Шутер, Для нескольких и...   9 / 10
# 1  Пошаговые сражения, Глубокий сюжет, Фэнтези, И...   9 / 10
# 2  Экшен, Шутер от первого лица, Демоны, Тёмное ф...   9 / 10
# 3  Симулятор, Кооператив, Криминал, Для нескольки...  10 / 10
# 4  Ролевая игра, Открытый мир, Фэнтези, Для одног...   9 / 10
#
#                                            prep_text  \
# 0  об этой игре более двух десятилетий counter st...
# 1  об этой игре раз в год художница просыпается и...
# 2  об этой игре станьте палачом в средневековой в...
# 3  об этой игре schedule i drugs substances or ch...
# 4  об этой игре the elder scrolls iv oblivion™ re...
#
#                                        tokenize_text  \
# 0  игре двух десятилетий counter strike служит пр...
# 1  игре год художница просыпается рисует монолите...
# 2  игре станьте палачом средневековой войне адомd...
# 3  игре schedule i drugs substances or chemicals ...
# 4  игре the elder scrolls iv oblivion™ remastered...
#
#                                            text_stem  \
# 0  игр двух десятилет counter strike служ пример ...
# 1  игр год художниц просыпа рис монол вывод сво п...
# 2  игр станьт палач средневеков войн адомдо the d...
# 3  игр schedule i drugs substances or chemicals a...
# 4  игр the elder scrolls iv обливион™ remastered ...
#
#                                            text_lemm
# 0  игра два десятилетие counter strike служить пр...
# 1  игра год художница просыпаться рисовать моноли...
# 2  игра стать палач средневековый война адомdoom ...
# 3  игра schedule i drugs substances or chemicals ...
# 4  игра the elder scrolls iv oblivion™ remastered...

# %%
df['text_lemm'][0]
# Out:
# 'игра два десятилетие counter strike служить пример первоклассный соревновательный игра путь развитие который определять миллион игрок мир прийти время новый этап counter strike counter strike бесплатный улучшение cs go который знаменовать себя крупный технологический скачок история серия оно разработать движок source модернизировать игра благодаря реалистичный физически корректный рендеринг организация сеть последний слово технология улучшить инструмент мастерская сообщество кроме представить год классический игровой процесс завязать достижение цель counter strike включать новый рейтинг cs обновить премьер режим глобальный региональный таблица лидер улучшить воссоздать нуль карта принципиально новый динамический дым гранат игровой процесс зависеть тикрейт переосмыслить визуальный эффект звук предмет инвентарь cs go'

# %%
df['text_lemm'] = [tokenize(text) for text in df['text_lemm']]

# %%
df.head()
# Out:
#    Unnamed: 0                                      title  \
# 0           0                           Counter-Strike 2
# 1           1                Clair Obscur: Expedition 33
# 2           2                        DOOM: The Dark Ages
# 3           3                                 Schedule I
# 4           4  The Elder Scrolls IV: Oblivion Remastered
#
#                                          description          date  \
# 0  Об этой игре Более двух десятилетий Counter-St...  21 Aug, 2012
# 1  Об этой игре Раз в год Художница просыпается и...  24 Apr, 2025
# 2  Об этой игре СТАНЬТЕ ПАЛАЧОМ В СРЕДНЕВЕКОВОЙ В...  14 May, 2025
# 3  Об этой игре Schedule I drugs, substances, or ...  24 Mar, 2025
# 4  Об этой игре The Elder Scrolls IV: Oblivion™ R...  22 Apr, 2025
#
#                                                 tags   rating  \
# 0  Шутер от первого лица, Шутер, Для нескольких и...   9 / 10
# 1  Пошаговые сражения, Глубокий сюжет, Фэнтези, И...   9 / 10
# 2  Экшен, Шутер от первого лица, Демоны, Тёмное ф...   9 / 10
# 3  Симулятор, Кооператив, Криминал, Для нескольки...  10 / 10
# 4  Ролевая игра, Открытый мир, Фэнтези, Для одног...   9 / 10
#
#                                            prep_text  \
# 0  об этой игре более двух десятилетий counter st...
# 1  об этой игре раз в год художница просыпается и...
# 2  об этой игре станьте палачом в средневековой в...
# 3  об этой игре schedule i drugs substances or ch...
# 4  об этой игре the elder scrolls iv oblivion™ re...
#
#                                        tokenize_text  \
# 0  игре двух десятилетий counter strike служит пр...
# 1  игре год художница просыпается рисует монолите...
# 2  игре станьте палачом средневековой войне адомd...
# 3  игре schedule i drugs substances or chemicals ...
# 4  игре the elder scrolls iv oblivion™ remastered...
#
#                                            text_stem  \
# 0  игр двух десятилет counter strike служ пример ...
# 1  игр год художниц просыпа рис монол вывод сво п...
# 2  игр станьт палач средневеков войн адомдо the d...
# 3  игр schedule i drugs substances or chemicals a...
# 4  игр the elder scrolls iv обливион™ remastered ...
#
#                                            text_lemm
# 0  игра десятилетие counter strike служить пример...
# 1  игра год художница просыпаться рисовать моноли...
# 2  игра стать палач средневековый война адомdoom ...
# 3  игра schedule i drugs substances or chemicals ...
# 4  игра the elder scrolls iv oblivion™ remastered...

# %% [markdown]
# # Облако слов

# %%
pip install WordCloud
# Out:
# Requirement already satisfied: WordCloud in c:\users\artembruh\anaconda3\lib\site-packages (1.9.4)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\artembruh\anaconda3\lib\site-packages (from WordCloud) (1.26.4)
# Requirement already satisfied: pillow in c:\users\artembruh\anaconda3\lib\site-packages (from WordCloud) (10.4.0)
# Requirement already satisfied: matplotlib in c:\users\artembruh\anaconda3\lib\site-packages (from WordCloud) (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\artembruh\anaconda3\lib\site-packages (from matplotlib->WordCloud) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\artembruh\anaconda3\lib\site-packages (from matplotlib->WordCloud) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\artembruh\anaconda3\lib\site-packages (from matplotlib->WordCloud) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\artembruh\anaconda3\lib\site-packages (from matplotlib->WordCloud) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\artembruh\anaconda3\lib\site-packages (from matplotlib->WordCloud) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\artembruh\anaconda3\lib\site-packages (from matplotlib->WordCloud) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\artembruh\anaconda3\lib\site-packages (from matplotlib->WordCloud) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\artembruh\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->WordCloud) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Получение текстовой строки из списка слов
def str_corpus(corpus):
    str_corpus = ''
    for i in corpus:
        str_corpus += ' ' + i
    str_corpus = str_corpus.strip()
    return str_corpus

# Получение списка всех слов в корпусе
def get_corpus(data):
    corpus = []
    for phrase in data:
        for word in phrase.split():
            corpus.append(word)
    return corpus

# Получение облака слов
def get_wordCloud(corpus):
    wordCloud = WordCloud(background_color='white',
                              stopwords=STOPWORDS,
                              width=3000,
                              height=2500,
                              max_words=200,
                              random_state=42
                         ).generate(str_corpus(corpus))
    return wordCloud

# %%
corpus = get_corpus(df['description'].values)
procWordCloud = get_wordCloud(corpus)

fig = plt.figure(figsize=(20, 8))
plt.subplot(1, 2, 1)
plt.imshow(procWordCloud)
plt.axis('off')
plt.subplot(1, 2, 1)
# Out:
# <Axes: >

# %%
corpus = get_corpus(df['text_lemm'].values)
procWordCloud = get_wordCloud(corpus)

fig = plt.figure(figsize=(20, 8))
plt.subplot(1, 2, 1)
plt.imshow(procWordCloud)
plt.axis('off')
plt.subplot(1, 2, 1)
# Out:
# <Axes: >

# %%
# Получение облака слов
def get_wordCloud2(corpus):
    wordCloud = WordCloud(background_color='white',
                              stopwords=STOPWORDS,
                              width=3000,
                              height=2500,
                              max_words=200,
                              random_state=42
                         ).generate(corpus)
    return wordCloud

# %%
corpus = df['text_lemm'][0]
procWordCloud = get_wordCloud2(corpus)

fig = plt.figure(figsize=(20, 8))
plt.subplot(1, 2, 1)
plt.imshow(procWordCloud)
plt.axis('off')
plt.subplot(1, 2, 1)
# Out:
# <Axes: >

# %%
corpus = df['text_lemm'][1]
procWordCloud = get_wordCloud2(corpus)

fig = plt.figure(figsize=(20, 8))
plt.subplot(1, 2, 1)
plt.imshow(procWordCloud)
plt.axis('off')
plt.subplot(1, 2, 1)
# Out:
# <Axes: >

# %%
df['text_lemm'][1]
# Out:
# 'игра год художница просыпаться рисовать монолит выводить проклятый число каждый чей возраст совпадать число обращаться дым угасать каждый год число уменьшаться завтра проснуться написать цифра отправляться последний экспедиция уничтожить художница экспедиция clair obscur expedition новый пошаговый ролевый игра уникальный механика реальный время невозможно оторваться исследовать мир создать основа прекрасный эпоха франция сражаться опасный враг новый jrpg действие реальный время дополнять классический пошаговый бой создать уникальный экспедиция использовать разнообразный снаряжение навык параметр взаимодействие участник выполнять уклонение парировать наносить контрудар реальный время собирать комбо осваивать ритм атака нацеливаться слабый место противник использовать система прицеливание остаться год присоединяться гюстав маэль участник экспедиция отчаянный путешествие разорвать порочный круг смерть создать художница пройти след предыдущий экспедиция узнать судьба познакомиться участник экспедиция предстоять работать вместе ради достижение цель исследовать чаровать мир населить сюрреалистический враг путешествовать захватывать пейзаж остров многоликий забытый поле бой открывать скрытый задание разгадывать тайна находить союзник среди существо легенда встречать уникальный компаньон использовать новый способ передвижение раскрывать тайный место карта познакомиться дебютный игра sandfall interactive создать база unreal engine ждать потрясать графика трогательный саундтрек'

# %%
corpus = df['text_lemm'][2]
procWordCloud = get_wordCloud2(corpus)

fig = plt.figure(figsize=(20, 8))
plt.subplot(1, 2, 1)
plt.imshow(procWordCloud)
plt.axis('off')
plt.subplot(1, 2, 1)
# Out:
# <Axes: >

# %%
df['text_lemm'][2]
# Out:
# 'игра стать палач средневековый война адомdoom the dark ages студия id software зрелищный сказание легендарный палач рок поведать предыстория снискать всемирный известность игра doom doom eternal третий часть современный серия doom игрок вновь надеть броня палач рок пролить река кровь мрачный средневековый война сила ад ещё видеть doom the dark ages новый одиночный кампания несравненный серия doom стык научный фантастика тёмный фэнтези ждать яростный сражение сногсшибательный графика основа движок idtech поспокорить ад рвать враг клок настоящий супероружие бог царь цель ваш распоряжение оказаться классический средство супердробовик смочь перемалывать кость враг масса новый оружие число универсальный щит пила игрок противостоять орда демон приготовиться безжалостный сражение дух оригинальный doom выходить сражаться узнать исток ярость палач рок прожить история обречь супероружие рука бог царь палач предстоять сдерживать натиск легион ад противостоять главарь цель стать единственный существо мир чей имя внушать страх значит уничтожить палач увидеть рождение легенда сразиться весь армия преисподняя переломить ход война открыть неизведанный мир сокрушить полчище ад палач должный обагрить кровь новый земля загадка испытание награда прятаться тенистый уголок древний замок огромный поле сражение мрачный лес древний чертог ад иной мир вооружиться мощный щит пила прорубить путь тёмный мир тайна опасность исследовать самый масштабный уровень история id'

# %% [markdown]
# # Векторизация текстовых данных

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
df['text_lemm'][0]
# Out:
# 'игра десятилетие counter strike служить пример первоклассный соревновательный игра путь развитие определять миллион игрок мир прийти время новый этап counter strike counter strike бесплатный улучшение cs go знаменовать крупный технологический скачок история серия оно разработать движок source модернизировать игра благодаря реалистичный физически корректный рендеринг организация сеть последний слово технология улучшить инструмент мастерская сообщество кроме представить год классический игровой процесс завязать достижение цель counter strike включать новый рейтинг cs обновить премьер режим глобальный региональный таблица лидер улучшить воссоздать нуль карта принципиально новый динамический дым гранат игровой процесс зависеть тикрейт переосмыслить визуальный эффект звук предмет инвентарь cs go'

# %%
vectorizer = CountVectorizer()
vectorizer.fit(df['text_lemm'])
# Out:
# CountVectorizer()

# %%
print(vectorizer.vocabulary_)
# Out:
# {'игра': 31162, 'десятилетие': 27108, 'counter': 3218, 'strike': 15146, 'служить': 57714, 'пример': 50923, 'первоклассный': 45989, 'соревновательный': 58448, 'путь': 52756, 'развитие': 53186, 'определять': 43953, 'миллион': 38227, 'игрок': 31183, 'мир': 38356, 'прийти': 50789, 'время': 23759, 'новый': 42257, 'этап': 67340, 'бесплатный': 20447, 'улучшение': 62693, 'cs': 3365, 'go': 6369, 'знаменовать': 30974, 'крупный': 35430, 'технологический': 60987, 'скачок': 57221, 'история': 32406, 'серия': 56772, 'оно': 43787, 'разработать': 53532, 'движок': 26587, 'source': 14761, 'модернизировать': 38656, 'благодаря': 20777, 'реалистичный': 54295, 'физически': 63773, 'корректный': 34842, 'рендеринг': 54704, 'организация': 44091, 'сеть': 56835, 'последний': 49461, 'слово': 57655, 'технология': 60990, 'улучшить': 62695, 'инструмент': 31928, 'мастерская': 37361, 'сообщество': 58363, 'кроме': 35357, 'представить': 50286, 'год': 25662, 'классический': 33577, 'игровой': 31177, 'процесс': 52409, 'завязать': 29330, 'достижение': 28195, 'цель': 65213, 'включать': 22882, 'рейтинг': 54564, 'обновить': 42792, 'премьер': 50401, 'режим': 54455, 'глобальный': 25549, 'региональный': 54361, 'таблица': 60308, 'лидер': 36259, 'воссоздать': 23571, 'нуль': 42446, 'карта': 32967, 'принципиально': 50999, 'динамический': 27494, 'дым': 28529, 'гранат': 26020, 'зависеть': 29269, 'тикрейт': 61046, 'переосмыслить': 46422, 'визуальный': 22702, 'эффект': 67389, 'звук': 30781, 'предмет': 50183, 'инвентарь': 31719, 'художница': 65070, 'просыпаться': 52216, 'рисовать': 55021, 'монолит': 38837, 'выводить': 24107, 'проклятый': 51796, 'число': 65785, 'каждый': 32585, 'чей': 65520, 'возраст': 23291, 'совпадать': 58126, 'обращаться': 42941, 'угасать': 62319, 'уменьшаться': 62745, 'завтра': 29318, 'проснуться': 52139, 'написать': 39985, 'цифра': 65374, 'отправляться': 44901, 'экспедиция': 66856, 'уничтожить': 62850, 'clair': 2603, 'obscur': 10974, 'expedition': 5128, 'пошаговый': 49923, 'ролевый': 55197, 'уникальный': 62837, 'механика': 37996, 'реальный': 54302, 'невозможно': 40635, 'оторваться': 44860, 'исследовать': 32362, 'создать': 58205, 'основа': 44307, 'прекрасный': 50371, 'эпоха': 67260, 'франция': 64209, 'сражаться': 59012, 'опасный': 43820, 'враг': 23716, 'jrpg': 8244, 'действие': 26829, 'дополнять': 28087, 'бой': 21008, 'использовать': 32313, 'разнообразный': 53467, 'снаряжение': 57945, 'навык': 39480, 'параметр': 45638, 'взаимодействие': 22428, 'участник': 63370, 'выполнять': 24444, 'уклонение': 62610, 'парировать': 45674, 'наносить': 39949, 'контрудар': 34572, 'собирать': 58043, 'комбо': 34122, 'осваивать': 44204, 'ритм': 55030, 'атака': 19460, 'нацеливаться': 40423, 'слабый': 57536, 'место': 37875, 'противник': 52248, 'система': 57083, 'прицеливание': 51245, 'остаться': 44388, 'присоединяться': 51127, 'гюстав': 26369, 'маэль': 37496, 'отчаянный': 45157, 'путешествие': 52749, 'разорвать': 53514, 'порочный': 49326, 'круг': 35398, 'смерть': 57816, 'пройти': 51758, 'след': 57574, 'предыдущий': 50330, 'узнать': 62557, 'судьба': 59884, 'познакомиться': 48380, 'предстоять': 50297, 'работать': 52925, 'вместе': 22990, 'ради': 52989, 'чаровать': 65458, 'населить': 40177, 'сюрреалистический': 60284, 'путешествовать': 52750, 'захватывать': 30619, 'пейзаж': 45925, 'остров': 44407, 'многоликий': 38529, 'забытый': 29207, 'поле': 48573, 'открывать': 44709, 'скрытый': 57481, 'задание': 29440, 'разгадывать': 53231, 'тайна': 60371, 'находить': 40413, 'союзник': 58657, 'среди': 59030, 'существо': 60093, 'легенда': 36033, 'встречать': 23925, 'компаньон': 34238, 'способ': 58922, 'передвижение': 46138, 'раскрывать': 53806, 'тайный': 60375, 'дебютный': 26725, 'sandfall': 13789, 'interactive': 7677, 'база': 19721, 'unreal': 16553, 'engine': 4823, 'ждать': 28859, 'потрясать': 49769, 'графика': 26053, 'трогательный': 61753, 'саундтрек': 56022, 'стать': 59261, 'палач': 45487, 'средневековый': 59034, 'война': 23312, 'адомdoom': 18351, 'the': 15780, 'dark': 3585, 'ages': 319, 'студия': 5976 ...

# %%
vectorizer = CountVectorizer(analyzer='word', stop_words=russian_stopwords, ngram_range=(1, 3), min_df=2)
count_matrix = vectorizer.fit_transform(df['text_lemm'])

# %%
count_matrix.shape
# Out:
# (870, 200841)

# %%
vectorizer.get_feature_names_out()[45000:46000]
# Out:
# array(['доверять полагаться знание', 'доверять разумеется',
#        'доверять разумеется использовать', 'довесок', 'довести',
#        'довести её', 'довести капитальный',
#        'довести капитальный сооружение', 'довести конец',
#        'довести проект', 'довести ум', 'довестись',
#        'довестись присоединиться', 'довестись присоединиться команда',
#        'довлеть', 'довлеть жёлтый', 'довлеть жёлтый красный', 'довод',
#        'довод рассудок', 'довод рассудок почему', 'доводить',
#        'доводить дело', 'доводить совершенство', 'доводить ум',
#        'доводиться', 'доводка', 'довольно', 'довольно агент',
#        'довольно агент личность', 'довольно безобидный',
#        'довольно безобидный развлечение', 'довольно безразличный',
#        'довольно болезненный', 'довольно больший', 'довольно большой',
#        'довольно большой красный', 'довольно большой проблема',
#        'довольно быстро', 'довольно быстро выясниться',
#        'довольно быстро скопление', 'довольно быстрый', 'довольно важный',
#        'довольно время', 'довольно высокий', 'довольно грубый',
#        'довольно давно', 'довольно далеко', 'довольно далеко связать',
#        'довольно длительный', 'довольно долгий', 'довольно долгий время',
#        'довольно долго', 'довольно долго автомобильный',
#        'довольно дорого', 'довольно дорого ой', 'довольно дорогой',
#        'довольно жестоко', 'довольно жестоко твой', 'довольно жёстко',
#        'довольно забавно', 'довольно забавно веселиться',
#        'довольно забавный', 'довольно затратный', 'довольно интересный',
#        'довольно компактный', 'довольно крутой', 'довольно легко',
#        'довольно мало', 'довольно массивный',
#        'довольно массивный электронный', 'довольно медленный',
#        'довольно место', 'довольно минималистичный', 'довольно молодой',
#        'довольно мягкий', 'довольно народ', 'довольно необычно',
#        'довольно необычный', 'довольно неплохой', 'довольно неприятный',
#        'довольно низкий', 'довольно обширный', 'довольно общий',
#        'довольно объёмный', 'довольно ограничить', 'довольно оскалиться',
#        'довольно оскалиться сразу', 'довольно острый',
#        'довольно откровенно', 'довольно очевидный',
#        'довольно очевидный сон', 'довольно плотно',
#        'довольно поверхностный', 'довольно подробно',
#        'довольно подробный', 'довольно пожилой', 'довольно поздно',
#        'довольно понятно', 'довольно понятно ребята',
#        'довольно популярный', 'довольно примитивный',
#        'довольно проблематично', 'довольно продвинуть', 'довольно просто',
#        'довольно просто сделать', 'довольно простой',
#        'довольно простой способ', 'довольно распространить',
#        'довольно редкий', 'довольно редкий увлечение', 'довольно редко',
#        'довольно сильно', 'довольно сильно поменяться',
#        'довольно сильный', 'довольно скоро', 'довольно скудный',
#        'довольно скучный', 'довольно сложно', 'довольно сложный',
#        'довольно сложный физический', 'довольно стандартный',
#        'довольно старый', 'довольно старый кой', 'довольно странно',
#        'довольно странный', 'довольно субъективный', 'довольно таки',
#        'довольно точно', 'довольно трудно', 'довольно тяжёлый',
#        'довольно удачный', 'довольно удобно', 'довольно удобный',
#        'довольно успешно', 'довольно устойчивый', 'довольно хороший',
#        'довольно часто', 'довольно частый', 'довольно человек',
#        'довольно широкий', 'довольно широко', 'довольно ёмко',
#        'довольный', 'довольный вид', 'довольный вид сбыться',
#        'довольный вообще', 'довольный вообще теория',
#        'довольный воспоминание', 'довольный воспоминание забытый',
#        'довольный жизнь', 'довольный клиент', 'довольный получиться',
#        'довольный приносить', 'довольный приносить деньга',
#        'довольный работа', 'довольный результат', 'довольный улыбка',
#        'довольный хотя', 'довольствоваться',
#        'довольствоваться путешествие',
#        'довольствоваться путешествие четыре', 'догадаться',
#        'догадаться интересно', 'догадаться огрызнуться',
#        'догадаться огрызнуться денис', 'догадаться помогать',
#        'догадаться помогать образ', 'догадаться понять',
#        'догадаться понять пояснить', 'догадаться почему',
#        'догадаться почему сексот', 'догадаться сделать', 'догадаться ход',
#        'догадаться ход дело', 'догадаться шахматы',
#        'догадаться шахматы пример', 'догадка', 'догадка блядь',
#        'догадка блядь знать', 'догадка макс', 'догадка макс родиться',
#        'догадываться', 'догадываться например', 'догадываться смысл',
#        'догадываться хотеть', 'догадываться хотеть ладный', 'догма',
#        'догнать', 'догнать дверь', 'догнать миг', 'догнать миг денис',
#        'догнать пахать', 'догнать пахать робот', 'договариваться',
#        'договариваться встреча', 'договариваться москва',
#        'договариваться москва системный', 'договариваться неужели',
#        'договариваться неужели устройство', 'договариваться нормально',
#        'договариваться нормально приехать', 'договариваться рой',
#        'договариваться рой очень', 'договариваться сотрудничество',
#        'договор', 'договор абонент', 'договор абонент предусмотреть',
#        'договор аренда', 'договор арумов', 'договор арумов совет',
#        'договор должный', 'договор заказчик', 'договор клиент',
#        'договор комбат', 'договор комбат решить', 'договор купля',
#        'договор купля продажа', 'договор макс', 'договор макс пугать',
#        'договор неразглашение', 'договор нужно', 'договор оператор',
#        'договор оператор участник', 'договор описать',
#        'договор описать немой', 'договор подписать', 'договор подряд',
#        'договор подумать', 'договор подумать макс', 'договор прописывать',
#        'договор прописывать условие', 'договор разработка',
#        'договор разработка сайт', 'договор сказать',
#        'договор сказать нужный', 'договор юрист', 'договорить',
#        'договорить первый', 'договорить первый случиться', 'договориться',
#        'договориться брать', 'договориться брать марс',
#        'договориться внести', 'договориться внести предоплата',
#        'договориться враг', 'договориться враг получить',
#        'договориться ещё', 'договориться использовать',
#        'договориться использовать порт', 'договориться каждый',
#        'договориться макс', 'договориться макс очень',
#        'договориться место', 'договориться сразу', 'договориться считать',
#        'договорённость', 'договорённость делать',
#        'договорённость оперативный', 'договорённость оперативный штаб',
#        'догонялки', 'догонять', 'догонять меланхолично',
#        'догонять меланхолично ответить', 'додайвиться',
#        'додайвиться появление', 'додайвиться появление тень', 'доделать',
#        'доделать задача', 'доделать поздний', 'доделка', 'доделывать',
#        'доделываться', 'додуматься', 'додуматься раздавить',
#        'додуматься раздавить счёт', 'доезжать', 'доесть', 'доехать',
#        'доехать изрядно', 'доехать изрядно потрепать', 'дожать',
#        'дождаться', 'дождаться вакцина', 'дождаться окончание',
#        'дождаться пока', 'дождаться пока бумажка', 'дождаться такси',
#        'дождаться такси затруднительный', 'дождик', 'дождливый',
#        'дождливый погода', 'дождь', 'дождь зелёный', 'дождь кстати',
#        'дождь кстати погода', 'дождь очень', 'дождь распасться',
#        'дождь распасться обязательно', 'доживать', 'дожидаться',
#        'дожидаться ответ', 'дожидаться пока', 'дожидаться пока дать',
#        'дожидаться полный', 'дожидаться приглашение',
#        'дожидаться приглашение новообразовавшийся', 'дожимать', 'дожить',
#        'дожить момент', 'дожить рой', 'дожить рой хотя', 'доза',
#        'доза больший', 'доза лучевой', 'доза маленький', 'доза облучение',
#        'доза получить', 'доза порядок', 'доза составлять',
#        'доза транквилизатор', 'доза человек', 'доза человек умирать',
#        'доза яд', 'доза яд полтора', 'дозаряд', 'дозатор',
#        'дозваниваться', 'дозволить', 'дозволить правда',
#        'дозволить правда самец', 'дозволяться', 'дозвон', 'дозвониться',
#        'дозвониться слушать', 'дозвониться слушать извинить', 'дозиметр',
#        'дозиметрический', 'дозировать', 'дозовый', 'доисторический',
#        'дойти', 'дойти время', 'дойти дверь', 'дойти дойти',
#        'дойти дойти пускай', 'дойти клиника', 'дойти клиника говорить',
#        'дойти конец', 'дойти пока', 'дойти прогресс',
#        'дойти прогресс боксёрский', 'дойти пускай', 'дойти пускай спать',
#        'дойти сегодняшний', 'дойти сегодняшний жизнь', 'дойти смысл',
#        'дойти уровень', 'дойча', 'док', 'док станция', 'доказательный',
#        'доказательный медицина', 'доказательство',
#        'доказательство определить', 'доказательство определить ответ',
#        'доказательство хотеть', 'доказательство хотеть верить',
#        'доказательство эффективность', 'доказать', 'доказать ваш',
#        'доказать достойный', 'доказать достойный получить',
#        'доказать методика', 'доказать мочь', 'доказать навык',
#        'доказать навык мочь', 'доказать полезность', 'доказать простой',
#        'доказать простой биологический', 'доказать работать',
#        'доказать существование', 'доказать существование высокий',
#        'доказать хороший', 'доказать хороший решение',
#        'доказать эффективность', 'доказывать', 'доказывать верблюд',
#        'доказывать либо', 'доказывать либо находиться', 'доказываться',
#        'докапываться', 'докапываться стратегический',
#        'докапываться стратегический объект', 'докатиться', 'докдок',
#        'докер', 'докер образ', 'докинуть', 'докинуть идти',
#        'докинуть идти основной', 'доклад', 'доклад devops',
#        'доклад highload', 'доклад ios', 'доклад rubyrussia',
#        'доклад rubyrussia рассказать', 'доклад автор', 'доклад активация',
#        'доклад активация обмен', 'доклад александр',
#        'доклад александр рассказать', 'доклад алексей',
#        'доклад английский', 'доклад английский перевод', 'доклад артём',
#        'доклад большинство', 'доклад весь', 'доклад весь lead',
#        'доклад вместе', 'доклад выложить', 'доклад выступить',
#        'доклад глеб', 'доклад глеб построить', 'доклад год',
#        'доклад делать', 'доклад джон', 'доклад дизайн', 'доклад доклад',
#        'доклад доклад александр', 'доклад достаточно', 'доклад екатерина',
#        'доклад ещё', 'доклад живой', 'доклад зал', 'доклад заявить',
#        'доклад звать', 'доклад иван', 'доклад интересно',
#        'доклад интересный', 'доклад йонатан', 'доклад йонатан поделиться',
#        'доклад компания', 'доклад конференция', 'доклад крутой',
#        'доклад кстати', 'доклад методология', 'доклад минута',
#        'доклад многий', 'доклад многий конференция', 'доклад написать',
#        'доклад например', 'доклад николай', 'доклад новый',
#        'доклад обратиться', 'доклад общение', 'доклад олег',
#        'доклад основать', 'доклад основать опыт', 'доклад очень',
#        'доклад первый', 'доклад писать', 'доклад поговорить',
#        'доклад поговорить жить', 'доклад поделиться', 'доклад пойти',
#        'доклад полезный', 'доклад получаться', 'доклад полчаса',
#        'доклад попасть', 'доклад посвятить', 'доклад посвятить atomic',
#        'доклад почему', 'доклад предыдущий', 'доклад презентация',
#        'доклад программа', 'доклад работа', 'доклад работать',
#        'доклад разный', 'доклад разобрать', 'доклад рассказать',
#        'доклад рассказать заложить', 'доклад рассказать сложность',
#        'доклад рассказывать', 'доклад рассмотреть', 'доклад сайт',
#        'доклад сделать', 'доклад сидеть', 'доклад состояние',
#        'доклад специалист', 'доклад спикер', 'доклад спикер показать',
#        'доклад стенд', 'доклад стенд хороший', 'доклад страница',
#        'доклад также', 'доклад узнать', 'доклад упомянуть',
#        'доклад участник', 'доклад хотеть', 'доклад час', 'докладчик',
#        'докладчик весь', 'докладчик выйти', 'докладчик говорить',
#        'докладывать', 'докладывать тайный',
#        'докладывать тайный повелитель', 'доковидный', 'доковидный время',
#        'докомпьютерный', 'докомпьютерный эра', 'докомпьютерный эра плохо',
#        'докопаться', 'докопаться суть', 'докопаться суть выяснить',
#        'докрутить', 'докручивания', 'доктор', 'доктор биологический',
#        'доктор биологический наука', 'доктор вести', 'доктор впору',
#        'доктор впору ваш', 'доктор ева', 'доктор ева шульц',
#        'доктор запустить', 'доктор запустить программа', 'доктор лишь',
#        'доктор лишь добродушно', 'доктор медицина', 'доктор наука',
#        'доктор нормально', 'доктор нормально зевнуть', 'доктор отто',
#        'доктор отто шульц', 'доктор посмотреть', 'доктор посмотреть лог',
#        'доктор прописать', 'доктор самый', 'доктор слегка',
#        'доктор слегка ошарашить', 'доктор чип', 'доктор чип обычно',
#        'докторский', 'документ', 'документ acm',
#        'документ acm ассоциация', 'документ word', 'документ год',
#        'документ далее', 'документ должный', 'документ ещё',
#        'документ знакомый', 'документ имя', 'документ интуитивно',
#        'документ интуитивно понятный', 'документ использовать',
#        'документ каждый', 'документ ладный', 'документ ладный пора',
#        'документ мочь', 'документ написать', 'документ например',
#        'документ никакой', 'документ новый', 'документ нормально',
#        'документ нужно', 'документ нужный', 'документ образование',
#        'документ отправить', 'документ отправляться', 'документ отчаяние',
#        'документ отчаяние называть', 'документ отчёт', 'документ первый',
#        'документ подписать', 'документ подтверждать',
#        'документ позволять', 'документ получение', 'документ понимать',
#        'документ понимать крошечный', 'документ постановление',
#        'документ постановление минкомсвязи', 'документ проблема',
#        'документ проект', 'документ просто', 'документ просто должный',
#        'документ просто расписаться', 'документ регламентировать',
#        'документ решение', 'документ связаться',
#        'документ связаться никто', 'документ сделать', 'документ сектор',
#        'документ сектор оптимизация', 'документ система',
#        'документ сказать', 'документ собрать',
#        'документ собрать проблема', 'документ соглашение',
#        'документ соглашение конфиденциальность', 'документ содержать',
#        'документ сторона', 'документ требоваться',
#        'документ удостоверять', 'документ удостоверять личность',
#        'документ федеральный', 'документ фиксировать', 'документ форма',
#        'документ формат', 'документ число', 'документальный',
#        'документальный фильм', 'документация', 'документация api',
#        'документация ваш', 'документация встроить', 'документация всё',
#        'документация довольно', 'документация документация',
#        'документация должный', 'документация ещё', 'документация код',
#        'документация мочь', 'документация написать',
#        'документация например', 'документация обычно',
#        'документация описание', 'документация писать',
#        'документация пример', 'документация продукт',
#        'документация снова', 'документация ссылка', 'документирование',
#        'документированный', 'документировать', 'документный',
#        'документооборот', 'докупить', 'докурить', 'долбануть',
#        'долбануть нормальный', 'долбануть нормальный надёжно', 'долбаный',
#        'долбаный балашиха', 'долбаный балашиха коляна',
#        'долбаный ботаник', 'долбаный ботаник пихать',
#        'долбаный контейнер', 'долбаный контейнер гермозон',
#        'долбаный контейнер серьёзно', 'долбаный отморозок',
#        'долбаный отморозок иметь', 'долбаный протокол',
#        'долбаный протокол пухлый', 'долбать', 'долбить', 'долг',
#        'долг буквально', 'долг вернуть', 'долг вернуть смерть',
#        'долг дать', 'долг дать валюта', 'долг деньга', 'долг доклад',
#        'долг доклад поговорить', 'долг первый', 'долг первый зарплата',
#        'долг придумать', 'долг придумать план', 'долг служба', 'долгий',
#        'долгий возможно', 'долгий время', 'долгий время делать',
#        'долгий время работать', 'долгий год', 'долгий год вели',
#        'долгий год засилье', 'долгий год охранять', 'долгий дискуссия',
#        'долгий долгий', 'долгий долгий тренировка', 'долгий дорога',
#        'долгий жизнь', 'долгий жизнь чудом', 'долгий знать',
#        'долгий история', 'долгий крючок', 'долгий крючок точно',
#        'долгий мерка', 'долгий мерка отрасль', 'долгий момент',
#        'долгий несколько', 'долгий несколько минута', 'долгий ночь',
#        'долгий ночь заговорить', 'долгий обычный', 'долгий ожидание',
#        'долгий ожидание редкий', 'долгий остальной', 'долгий отношение',
#        'долгий отсутствие', 'долгий отсутствие перспектива',
#        'долгий период', 'долгий поездка', 'долгий пожалуйста',
#        'долгий пожалуйста пожалуйста', 'долгий полчаса',
#        'долгий полчаса мочь', 'долгий прийтись', 'долгий прожить',
#        'долгий путь', 'долгий пять', 'долгий пять секунда',
#        'долгий работа', 'долгий работать', 'долгий рабочий',
#        'долгий секунда', 'долгий скучный', 'долгий скучный вечер',
#        'долгий сложный', 'долгий срок', 'долгий страшный',
#        'долгий страшный мучение', 'долгий таскаться',
#        'долгий таскаться москва', 'долгий тренировка',
#        'долгий тренировка человек', 'долгий цикл', 'долгий час',
#        'долгий ящик', 'долго', 'долго автомобильный',
#        'долго автомобильный пробка', 'долго бегать', 'долго бить',
#        'долго бить башка', 'долго будущее', 'долго будущее наступить',
#        'долго весь', 'долго время', 'долго выбирать', 'долго делать',
#        'долго держать', 'долго дорого', 'долго думать',
#        'долго думать решить', 'долго ждать', 'долго жить',
#        'долго заниматься', 'долго идти', 'долго искать',
#        'долго использоваться', 'долго концентрироваться', 'долго коротко',
#        'долго ладно', 'долго ладно давать', 'долго летать',
#        'долго листать', 'долго медленно', 'долго мочь',
#        'долго мочь понять', 'долго мучительный', 'долго находиться',
#        'долго несколько', 'долго нужно', 'долго общаться',
#        'долго объяснять', 'долго оставаться', 'долго отвечать',
#        'долго пока', 'долго покрутить', 'долго покрутить кинцо',
#        'долго примерно', 'долго продолжаться', 'долго продолжаться мочь',
#        'долго происходить', 'долго протянуть', 'долго протянуть парка',
#        'долго пытаться', 'долго работать', 'долго работать сектор',
#        'долго раздаваться', 'долго рассказывать', 'долго рынок',
#        'долго сидеть', 'долго слушать', 'долго смочь', 'долго собираться',
#        'долго сонний', 'долго сонний даймона', 'долго спорить',
#        'долго спорить собеседник', 'долго стать', 'долго страстно',
#        'долго страстно хотеть', 'долго счастливо',
#        'долго счастливо скорее', 'долго упорно',
#        'долго упорно готовиться', 'долго учиться', 'долго ходить',
#        'долго хотеть', 'долго человек', 'долговечность', 'долговечный',
#        'долговой', 'долговременный', 'долговременный память',
#        'долговременный хранение', 'долгожданный', 'долгожданный отпуск',
#        'долгожданный отпуск почему', 'долгоиграющий', 'долголенко',
#        'долголенко владимир', 'долголенко владимир верещагин',
#        'долгосрочный', 'долгосрочный инвестиция', 'долгосрочный обучение',
#        'долгосрочный память', 'долгосрочный перспектива', 'долгота',
#        'долетать', 'долетать марс', 'долетать марс пять',
#        'долетать привычный', 'долетать привычный город', 'долететь',
#        'долететь окрестный', 'долететь окрестный жилец',
#        'долететь особый', 'долететь особый происшествие',
#        'долететь ответить', 'долететь ответить руслан',
#        'долететь стеклянный', 'долететь стеклянный дверь',
#        'долженствовать', 'должник', 'должное', 'должное человек',
#        'должное человек стать', 'должностной', 'должностной инструкция',
#        'должностной инструкция отступать', 'должностной лицо',
#        'должность', 'должность team', 'должность team lead',
#        'должность антон', 'должность ведущий',
#        'должность ведущий разработчик', 'должность генеральный',
#        'должность генеральный директор', 'должность компания',
#        'должность момент', 'должность начинать', 'должность некий',
#        'должность некий повелитель', 'должность положить',
#        'должность положить павлович', 'должность прим',
#        'должность прим хотеть', 'должность программист',
#        'должность программист оптимизатор', 'должность разработчика',
#        'должность разработчика скорее', 'должность региональный',
#        'должность региональный куратор', 'должность сектор',
#        'должность сектор определённый', 'должность стать',
#        'должность стать неприятный', 'должность требовать',
#        'должность хороший', 'должность хороший образ', 'должный',
#        'должный автоматически', 'должный активный',
#        'должный амортизировать', 'должный амортизировать время',
#        'должный асинхронный', 'должный баланс', 'должный бесплатный',
#        'должный беспокоиться', 'должный больший', 'должный брать',
#        'должный быстро', 'должный быстрый', 'должный важный',
#        'должный ваш', 'должный вернуть', 'должный вести',
#        'должный вести переговоры', 'должный взаимодействовать',
#        'должный взять', 'должный вид', 'должный видеть',
#        'должный видимый', 'должный видный', 'должный включать',
#        'должный включить', 'должный вкус', 'должный владеть',
#        'должный внести', 'должный внутри', 'должный воевать',
#        'должный возвращать', 'должный возможность', 'должный возникать',
#        'должный возникнуть', 'должный вообще', 'должный востребовать',
#        'должный вспомнить', 'должный вспомнить погодить',
#        'должный вспомнить часть', 'должный всё', 'должный входить',
#        'должный выбрать', 'должный выглядеть', 'должный выдавать',
#        'должный выдать', 'должный выдать следующий', 'должный выделить',
#        'должный выделить отдельный', 'должный вызывать', 'должный выйти',
#        'должный выполнить', 'должный выполнять', 'должный выполняться',
#        'должный вырасти', 'должный выходить', 'должный выяснить',
#        'должный выяснить плохо', 'должный генерироваться',
#        'должный говорить', 'должный говорить арумов', 'должный гореть',
#        'должный готовый', 'должный готовый взять', 'должный давать',
#        'должный дать', 'должный двадцать', 'должный двадцать пять',
#        'должный двигаться', 'должный действительно',
#        'должный действительно попытаться', 'должный действовать',
#        'должный действовать договор', 'должный делать',
#        'должный делать андрей', 'должный делать глобально',
#        'должный делаться', 'должный дело', 'должный дело бегать',
#        'должный держать', 'должный длиться', 'должный добавить',
#        'должный доверять', 'должный довольно', 'должный довольный',
#        'должный довольный вид', 'должный доказать', 'должный докопаться',
#        'должный докопаться суть', 'должный долгий', 'должный должный',
#        'должный достаточно', 'должный достаточно разнообразный',
#        'должный достаточный', 'должный достигнуть', 'должный доступный',
#        'должный думать', 'должный единомышленник', 'должный единственный',
#        'должный единый', 'должный её', 'должный ждать', 'должный жить',
#        'должный заботиться', 'должный завтра', 'должный завтра улететь',
#        'должный задать', 'должный задать узнать', 'должный задаться',
#        'должный задаться вопрос', 'должный задача',
#        'должный заканчиваться', 'должный закончиться', 'должный закрытый',
#        'должный заметить', 'должный заниматься',
#        'должный заниматься любой', 'должный заниматься снабженцы',
#        'должный заниматься хотеть', 'должный запускаться',
#        'должный запустить', 'должный звонить', 'должный звонить радостно'],
#       dtype=object)

# %%
vectorizer.get_feature_names_out()[3087]
# Out:
# 'expansions'

# %%
vectorizer.get_feature_names_out()[25765]
# Out:
# 'водянистый глаз'

# %%
print(count_matrix)
# Out:
#   (0, 58798)	3
#   (0, 43372)	1
#   (0, 1935)	4
#   (0, 9157)	4
#   (0, 164194)	1
#   (0, 134575)	1
#   (0, 113704)	1
#   (0, 168643)	1
#   (0, 143189)	1
#   (0, 146181)	1
#   (0, 105964)	1
#   (0, 84224)	1
#   (0, 59174)	1
#   (0, 84717)	1
#   (0, 133649)	1
#   (0, 28542)	1
#   (0, 98589)	3
#   (0, 199631)	1
#   (0, 15451)	1
#   (0, 185116)	1
#   (0, 2015)	3
#   (0, 3801)	2
#   (0, 74929)	1
#   (0, 179979)	1
#   (0, 161907)	1
#   :	:
#   (869, 21718)	1
#   (869, 189854)	2
#   (869, 113321)	1
#   (869, 123400)	1
#   (869, 36184)	1
#   (869, 46613)	2
#   (869, 46626)	1
#   (869, 46628)	1
#   (869, 61552)	1
#   (869, 187644)	1
#   (869, 115812)	1
#   (869, 104988)	1
#   (869, 123401)	1
#   (869, 36185)	1
#   (869, 189908)	1
#   (869, 7221)	1
#   (869, 138671)	1
#   (869, 37680)	1
#   (869, 167481)	1
#   (869, 189880)	1
#   (869, 38160)	3
#   (869, 153151)	1
#   (869, 168394)	1
#   (869, 8267)	1
#   (869, 8268)	1

# %% [markdown]
# 3. TF-IDF

# %% [markdown]
# __TF-IDF__ - это способ векторизации текста, отражающий важность слова в документе, а не только частоту его появления. В тексте большого объема некоторые слова могут присутствовать очень часто, но при этом не нести никакой значимой информации о фактическом содержании текста (документа). Если такие данные передавать непосредственно классификатору, то такие частые термины могут затенять частоты более редких, но при этом более интересных терминов. Для того, чтобы этого избежать, достаточно разделить количество употреблений каждого слова в документе на общее количество слов в документе, это есть TF — частота термина. Термин IDF (inverse document frequency) обозначает обратную частоту термина (инверсия частоты) с которой некоторое слово встречается в документах. IDF позволяет измерить непосредственную важность термина.

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
tfidf_vectorizer = TfidfVectorizer(max_df=0.8, max_features=10000,
                                 min_df=0.01, stop_words=russian_stopwords,
                                 ngram_range=(1,3))

# %%
# %%time
tfidf_matrix = tfidf_vectorizer.fit_transform(df['text_lemm'])
# Out:
# CPU times: total: 10.2 s
# Wall time: 10.5 s

# %%
tfidf_matrix.shape
# Out:
# (870, 10000)

# %%
tfidf_vectorizer.get_feature_names_out()[:100]
# Out:
# array(['about', 'academy', 'access', 'accessibility', 'action', 'active',
#        'add', 'address', 'adobe', 'advanced', 'after', 'agency', 'agile',
#        'ai', 'aic', 'air', 'airbnb', 'aka', 'all', 'alpha', 'am',
#        'amazon', 'an', 'analysis', 'analytics', 'and', 'and the',
#        'android', 'android ios', 'android разработка',
#        'android разработчик', 'any', 'apache', 'api', 'app', 'apple',
#        'application', 'applications', 'apps', 'ar', 'architecture',
#        'arduino', 'are', 'args', 'arm', 'art', 'artlebedev',
#        'artlebedev ru', 'as', 'async', 'at', 'audio', 'auto', 'avito',
#        'awards', 'aws', 'azure', 'back', 'backend', 'background', 'badoo',
#        'base', 'based', 'bash', 'be', 'before', 'begin', 'best', 'beyond',
#        'big', 'big data', 'bin', 'bit', 'black', 'block', 'blog', 'blue',
#        'bluetooth', 'body', 'bookmate', 'bootstrap', 'box', 'brain',
#        'brand', 'break', 'buffer', 'build', 'building', 'business', 'but',
#        'by', 'ca', 'cache', 'call', 'can', 'capital', 'card', 'case',
#        'catch', 'cc'], dtype=object)

# %%
tfidf_vectorizer.get_feature_names_out()[1253]
# Out:
# 'больший данные'

# %%
tfidf_vectorizer.get_feature_names_out()[5866]print(tfidf_matrix)
# Out:
# 'пережить'

# %%
print(tfidf_matrix)
# Out:
#   (0, 3165)	0.1597501277969354
#   (0, 2403)	0.096857673716932
#   (0, 144)	0.5078082134182177
#   (0, 8180)	0.08261085668282477
#   (0, 6858)	0.04363426418028483
#   (0, 7258)	0.05003066143597026
#   (0, 7372)	0.04954697250768189
#   (0, 5344)	0.0697156029072975
#   (0, 4290)	0.06203200404730688
#   (0, 3173)	0.07351124500213484
#   (0, 4317)	0.0422403919822646
#   (0, 6826)	0.051028274897742136
#   (0, 1765)	0.031016104098169624
#   (0, 4951)	0.09382742491593678
#   (0, 9938)	0.05569843331394736
#   (0, 1156)	0.06384324577391955
#   (0, 9220)	0.07287060956499032
#   (0, 152)	0.39399556700080224
#   (0, 298)	0.17273333067157787
#   (0, 3928)	0.051717136583961036
#   (0, 8909)	0.07204216866991649
#   (0, 8077)	0.12159160854909964
#   (0, 3443)	0.04585530635924897
#   (0, 7992)	0.07461846425500686
#   (0, 5303)	0.051456493102700826
#   :	:
#   (869, 9573)	0.1384167841908995
#   (869, 5726)	0.13546774452126037
#   (869, 8365)	0.10266404618993868
#   (869, 1053)	0.0800350172760327
#   (869, 3989)	0.07810929398265458
#   (869, 8706)	0.08562492916463685
#   (869, 1054)	0.08121444756696161
#   (869, 8707)	0.08602152099678785
#   (869, 5273)	0.07027693238280938
#   (869, 4100)	0.12513076698800607
#   (869, 7002)	0.12252317690401368
#   (869, 3288)	0.13740319963362357
#   (869, 2052)	0.26383368064685764
#   (869, 9082)	0.3795571178169938
#   (869, 2256)	0.1557718334058214
#   (869, 6992)	0.11953733581020327
#   (869, 2907)	0.12581735757769225
#   (869, 9480)	0.18530091175166657
#   (869, 6347)	0.10937062658419339
#   (869, 2577)	0.25303807854466254
#   (869, 2578)	0.1493653749109593
#   (869, 2579)	0.15953208413696918
#   (869, 9352)	0.13642080729371264
#   (869, 5954)	0.11897227270618213
#   (869, 6348)	0.1557718334058214
