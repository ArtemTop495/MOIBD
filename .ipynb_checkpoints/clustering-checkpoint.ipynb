# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn import datasets
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans, DBSCAN, AgglomerativeClustering
from sklearn.decomposition import PCA
from scipy.cluster.hierarchy import dendrogram, linkage

# %%
# Загрузка датасета iris
data = datasets.load_iris()
df = pd.DataFrame(data.data, columns=data.feature_names)
df['target'] = data.target

# %%
# Описание датасета
print("Описание датасета Iris:")
print(data.DESCR)
# Out:
# Описание датасета Iris:
# .. _iris_dataset:
#
# Iris plants dataset
# --------------------
#
# **Data Set Characteristics:**
#
# :Number of Instances: 150 (50 in each of three classes)
# :Number of Attributes: 4 numeric, predictive attributes and the class
# :Attribute Information:
#     - sepal length in cm
#     - sepal width in cm
#     - petal length in cm
#     - petal width in cm
#     - class:
#             - Iris-Setosa
#             - Iris-Versicolour
#             - Iris-Virginica
#
# :Summary Statistics:
#
# ============== ==== ==== ======= ===== ====================
#                 Min  Max   Mean    SD   Class Correlation
# ============== ==== ==== ======= ===== ====================
# sepal length:   4.3  7.9   5.84   0.83    0.7826
# sepal width:    2.0  4.4   3.05   0.43   -0.4194
# petal length:   1.0  6.9   3.76   1.76    0.9490  (high!)
# petal width:    0.1  2.5   1.20   0.76    0.9565  (high!)
# ============== ==== ==== ======= ===== ====================
#
# ...

# %%
# Разведочный анализ данных
print("\nИнформация о данных:")
print(df.info())
# Out:
# Информация о данных:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sepal length (cm)  150 non-null    float64
#  1   sepal width (cm)   150 non-null    float64
#  2   petal length (cm)  150 non-null    float64
#  3   petal width (cm)   150 non-null    float64
#  4   target             150 non-null    int32
# dtypes: float64(4), int32(1)
# memory usage: 5.4 KB
# None

# %%
print("\nСтатистическое описание данных:")
print(df.describe())
# Out:
# Статистическое описание данных:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)      target
# count        150.000000  150.000000
# mean           1.199333    1.000000
# std            0.762238    0.819232
# min            0.100000    0.000000
# 25%            0.300000    0.000000
# 50%            1.300000    1.000000
# 75%            1.800000    2.000000
# max            2.500000    2.000000

# %%
# Проверка на пропущенные значения
print("\nКоличество пропущенных значений в каждом столбце:")
print(df.isnull().sum())
# Out:
# Количество пропущенных значений в каждом столбце:
# sepal length (cm)    0
# sepal width (cm)     0
# petal length (cm)    0
# petal width (cm)     0
# target               0
# dtype: int64

# %%
# Корреляции между переменными
plt.figure(figsize=(8, 6))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Корреляции между переменными")
plt.show()

# %%
# Распределение данных
plt.figure(figsize=(10, 6))
df.drop(columns=['target']).hist(bins=20, figsize=(10, 6))
plt.suptitle("Гистограммы распределения переменных")
plt.show()

# %%
# Визуализация распределения данных с помощью pairplot
sns.pairplot(df, hue='target', diag_kind='kde')
plt.suptitle("Парные графики признаков с разметкой классов", y=1.02)
plt.show()

# %%
# Нормализация данных
scaler = StandardScaler()
scaled_data = scaler.fit_transform(df.drop(columns=['target']))
df_scaled = pd.DataFrame(scaled_data, columns=data.feature_names)

# %%
# Проверка средних значений и стандартных отклонений после нормализации
print("\nСредние значения после нормализации:")
print(df_scaled.mean(axis=0))
# Out:
# Средние значения после нормализации:
# sepal length (cm)   -1.690315e-15
# sepal width (cm)    -1.842970e-15
# petal length (cm)   -1.698641e-15
# petal width (cm)    -1.409243e-15
# dtype: float64

# %%
print("\nСтандартные отклонения после нормализации:")
print(df_scaled.std(axis=0))
# Out:
# Стандартные отклонения после нормализации:
# sepal length (cm)    1.00335
# sepal width (cm)     1.00335
# petal length (cm)    1.00335
# petal width (cm)     1.00335
# dtype: float64

# %%
# Применение PCA для визуализации
pca = PCA(n_components=2)
reduced_data = pca.fit_transform(scaled_data)
df_pca = pd.DataFrame(reduced_data, columns=['PC1', 'PC2'])

# %%
# Дендрограмма для иерархической кластеризации
linked = linkage(scaled_data, method='ward')
plt.figure(figsize=(10, 7))
dendrogram(linked)
plt.title("Dendrogram")
plt.show()

# %%
# Кластеризация K-Means
kmeans = KMeans(n_clusters=3, random_state=42)
kmeans_labels = kmeans.fit_predict(scaled_data)
df_pca['KMeans'] = kmeans_labels

plt.figure(figsize=(8, 6))
sns.scatterplot(x='PC1', y='PC2', hue=kmeans_labels, palette='Set1', data=df_pca)
plt.title("K-Means Clustering")
plt.show()

# %%
# Кластеризация DBSCAN
dbscan = DBSCAN(eps=1.0, min_samples=5)
dbscan_labels = dbscan.fit_predict(scaled_data)
df_pca['DBSCAN'] = dbscan_labels

plt.figure(figsize=(8, 6))
sns.scatterplot(x='PC1', y='PC2', hue=dbscan_labels, palette='Set1', data=df_pca)
plt.title("DBSCAN Clustering")
plt.show()

# %%
# Иерархическая кластеризация
agglo = AgglomerativeClustering(n_clusters=3)
agglo_labels = agglo.fit_predict(scaled_data)
df_pca['Agglomerative'] = agglo_labels

plt.figure(figsize=(5, 5))
sns.scatterplot(x='PC1', y='PC2', hue=agglo_labels, palette='Set1', data=df_pca)
plt.title("Agglomerative Clustering")
plt.show()

# %%
# Сравнение результатов кластеризации
print("\nРаспределение меток K-Means:")
print(pd.Series(kmeans_labels).value_counts())

print("\nРаспределение меток DBSCAN:")
print(pd.Series(dbscan_labels).value_counts())

print("\nРаспределение меток Agglomerative Clustering:")
print(pd.Series(agglo_labels).value_counts())
# Out:
# Распределение меток K-Means:
# 0    96
# 1    33
# 2    21
# Name: count, dtype: int64
#
# Распределение меток DBSCAN:
#  1    98
#  0    49
# -1     3
# Name: count, dtype: int64
#
# Распределение меток Agglomerative Clustering:
# 0    71
# 1    49
# 2    30
# Name: count, dtype: int64

# %%
# Визуальное сравнение кластерных распределений
fig, axes = plt.subplots(1, 3, figsize=(18, 5))
sns.scatterplot(x='PC1', y='PC2', hue=kmeans_labels, palette='Set1', data=df_pca, ax=axes[0])
axes[0].set_title("K-Means")
sns.scatterplot(x='PC1', y='PC2', hue=dbscan_labels, palette='Set1', data=df_pca, ax=axes[1])
axes[1].set_title("DBSCAN")
sns.scatterplot(x='PC1', y='PC2', hue=agglo_labels, palette='Set1', data=df_pca, ax=axes[2])
axes[2].set_title("Agglomerative")
plt.show()
