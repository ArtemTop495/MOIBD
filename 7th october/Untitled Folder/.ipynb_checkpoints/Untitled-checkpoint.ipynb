# %%
import sys
print(sys.version)
# Out:
# 3.10.19 | packaged by Anaconda, Inc. | (main, Oct 21 2025, 16:41:31) [MSC v.1929 64 bit (AMD64)]

# %%
pip install --upgrade pip tensorflow==2.8.0
# Out:
# Requirement already satisfied: pip in c:\users\artembruh\.conda\envs\my_env\lib\site-packages (25.2)
# Collecting pip
#   Using cached pip-25.3-py3-none-any.whl.metadata (4.7 kB)
# Collecting tensorflow==2.8.0
#   Using cached tensorflow-2.8.0-cp310-cp310-win_amd64.whl.metadata (2.9 kB)
# Collecting absl-py>=0.4.0 (from tensorflow==2.8.0)
#   Using cached absl_py-2.3.1-py3-none-any.whl.metadata (3.3 kB)
# Collecting astunparse>=1.6.0 (from tensorflow==2.8.0)
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl.metadata (4.4 kB)
# Collecting flatbuffers>=1.12 (from tensorflow==2.8.0)
#   Using cached flatbuffers-25.9.23-py2.py3-none-any.whl.metadata (875 bytes)
# Collecting gast>=0.2.1 (from tensorflow==2.8.0)
#   Using cached gast-0.6.0-py3-none-any.whl.metadata (1.3 kB)
# Collecting google-pasta>=0.1.1 (from tensorflow==2.8.0)
#   Using cached google_pasta-0.2.0-py3-none-any.whl.metadata (814 bytes)
# Collecting h5py>=2.9.0 (from tensorflow==2.8.0)
#   Using cached h5py-3.15.1-cp310-cp310-win_amd64.whl.metadata (3.1 kB)
# Collecting keras-preprocessing>=1.1.1 (from tensorflow==2.8.0)
#   Using cached Keras_Preprocessing-1.1.2-py2.py3-none-any.whl.metadata (1.9 kB)
# Collecting libclang>=9.0.1 (from tensorflow==2.8.0)
#   Using cached libclang-18.1.1-py2.py3-none-win_amd64.whl.metadata (5.3 kB)
# Collecting numpy>=1.20 (from tensorflow==2.8.0)
#   Using cached numpy-2.2.6-cp310-cp310-win_amd64.whl.metadata (60 kB)
# Collecting opt-einsum>=2.3.2 (from tensorflow==2.8.0)
#   Using cached opt_einsum-3.4.0-py3-none-any.whl.metadata (6.3 kB)
# Collecting protobuf>=3.9.2 (from tensorflow==2.8.0)
#   Using cached protobuf-6.33.0-cp310-abi3-win_amd64.whl.metadata (593 bytes)
# Requirement already satisfied: setuptools in c:\users\artembruh\.conda\envs\my_env\lib\site-packages (from tensorflow==2.8.0) (80.9.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\artembruh\.conda\envs\my_env\lib\site-packages (from tensorflow==2.8.0) (1.17.0)
# Collecting termcolor>=1.1.0 (from tensorflow==2.8.0)
#   Using cached termcolor-3.2.0-py3-none-any.whl.metadata (6.4 kB)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\artembruh\.conda\envs\my_env\lib\site-packages (from tensorflow==2.8.0) (4.15.0)
# Collecting wrapt>=1.11.0 (from tensorflow==2.8.0)
#   Using cached wrapt-2.0.0-cp310-cp310-win_amd64.whl.metadata (9.0 kB)
# Collecting tensorboard<2.9,>=2.8 (from tensorflow==2.8.0)
#   Using cached tensorboard-2.8.0-py3-none-any.whl.metadata (1.9 kB)
# Collecting tf-estimator-nightly==2.8.0.dev2021122109 (from tensorflow==2.8.0)
#   Using cached tf_estimator_nightly-2.8.0.dev2021122109-py2.py3-none-any.whl.metadata (1.2 kB)
# Collecting keras<2.9,>=2.8.0rc0 (from tensorflow==2.8.0)
#   Using cached keras-2.8.0-py2.py3-none-any.whl.metadata (1.3 kB)
# Collecting tensorflow-io-gcs-filesystem>=0.23.1 (from tensorflow==2.8.0)
#   Using cached tensorflow_io_gcs_filesystem-0.31.0-cp310-cp310-win_amd64.whl.metadata (14 kB)
# Collecting grpcio<2.0,>=1.24.3 (from tensorflow==2.8.0)
#   Using cached grpcio-1.76.0-cp310-cp310-win_amd64.whl.metadata (3.8 kB)
# Collecting google-auth<3,>=1.6.3 (from tensorboard<2.9,>=2.8->tensorflow==2.8.0)
#   Using cached google_auth-2.42.0-py2.py3-none-any.whl.metadata (6.6 kB)
# Collecting google-auth-oauthlib<0.5,>=0.4.1 (from tensorboard<2.9,>=2.8->tensorflow==2.8.0)
#   Using cached google_auth_oauthlib-0.4.6-py2.py3-none-any.whl.metadata (2.7 kB)
# Collecting markdown>=2.6.8 (from tensorboard<2.9,>=2.8->tensorflow==2.8.0)
#   Using cached markdown-3.9-py3-none-any.whl.metadata (5.1 kB)
# Collecting requests<3,>=2.21.0 (from tensorboard<2.9,>=2.8->tensorflow==2.8.0)
#   Using cached requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# Collecting tensorboard-data-server<0.7.0,>=0.6.0 (from tensorboard<2.9,>=2.8->tensorflow==2.8.0)
#   Using cached tensorboard_data_server-0.6.1-py3-none-any.whl.metadata (1.1 kB)
# Collecting tensorboard-plugin-wit>=1.6.0 (from tensorboard<2.9,>=2.8->tensorflow==2.8.0)
#   Using cached tensorboard_plugin_wit-1.8.1-py3-none-any.whl.metadata (873 bytes)
# Collecting werkzeug>=0.11.15 (from tensorboard<2.9,>=2.8->tensorflow==2.8.0)
#   Using cached werkzeug-3.1.3-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: wheel>=0.26 in c:\users\artembruh\.conda\envs\my_env\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8.0) (0.45.1)
# Collecting cachetools<7.0,>=2.0.0 (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow==2.8.0)
#   Using cached cachetools-6.2.1-py3-none-any.whl.metadata (5.5 kB)
# Collecting pyasn1-modules>=0.2.1 (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow==2.8.0)
#   Using cached pyasn1_modules-0.4.2-py3-none-any.whl.metadata (3.5 kB)
# Collecting rsa<5,>=3.1.4 (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow==2.8.0)
#   Using cached rsa-4.9.1-py3-none-any.whl.metadata (5.6 kB)
# Collecting requests-oauthlib>=0.7.0 (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow==2.8.0)
#   Using cached requests_oauthlib-2.0.0-py2.py3-none-any.whl.metadata (11 kB)
# Collecting charset_normalizer<4,>=2 (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow==2.8.0)
#   Using cached charset_normalizer-3.4.4-cp310-cp310-win_amd64.whl.metadata (38 kB)
# Collecting idna<4,>=2.5 (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow==2.8.0)
#   Using cached idna-3.11-py3-none-any.whl.metadata (8.4 kB)
# Collecting urllib3<3,>=1.21.1 (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow==2.8.0)
#   Using cached urllib3-2.5.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting certifi>=2017.4.17 (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow==2.8.0)
#   Using cached certifi-2025.10.5-py3-none-any.whl.metadata (2.5 kB)
# Collecting pyasn1>=0.1.3 (from rsa<5,>=3.1.4->google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow==2.8.0)
#   Using cached pyasn1-0.6.1-py3-none-any.whl.metadata (8.4 kB)
# Collecting oauthlib>=3.0.0 (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow==2.8.0)
#   Using cached oauthlib-3.3.1-py3-none-any.whl.metadata (7.9 kB)
# Collecting MarkupSafe>=2.1.1 (from werkzeug>=0.11.15->tensorboard<2.9,>=2.8->tensorflow==2.8.0)
#   Using cached markupsafe-3.0.3-cp310-cp310-win_amd64.whl.metadata (2.8 kB)
# Downloading tensorflow-2.8.0-cp310-cp310-win_amd64.whl (438.0 MB)
#    ---------------------------------------- 0.0/438.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/438.0 MB ? eta -:--:--
#    ---------------------------------------- 1.8/438.0 MB 9.1 MB/s eta 0:00:48
#     --------------------------------------- 9.2/438.0 MB 25.9 MB/s eta 0:00:17
#    - -------------------------------------- 11.8/438.0 MB 20.5 MB/s eta 0:00:21
#    - -------------------------------------- 14.7/438.0 MB 18.1 MB/s eta 0:00:24
#    -- ------------------------------------- 22.3/438.0 MB 21.3 MB/s eta 0:00:20
#    -- ------------------------------------- 32.2/438.0 MB 25.6 MB/s eta 0:00:16
#    --- ------------------------------------ 40.9/438.0 MB 28.3 MB/s eta 0:00:15
#    ---- ----------------------------------- 48.5/438.0 MB 28.8 MB/s eta 0:00:14
#    ----- ---------------------------------- 59.2/438.0 MB 31.2 MB/s eta 0:00:13
#    ------ --------------------------------- 67.9/438.0 MB 32.3 MB/s eta 0:00:12
#    ------- -------------------------------- 77.3/438.0 MB 33.3 MB/s eta 0:00:11
#    ------- -------------------------------- 87.6/438.0 MB 34.5 MB/s eta 0:00:11
#    -------- ------------------------------- 97.3/438.0 MB 35.5 MB/s eta 0:00:10
#    --------- ----------------------------- 107.7/438.0 MB 36.2 MB/s eta 0:00:10
#    ---------- ---------------------------- 117.4/438.0 MB 36.9 MB/s eta 0:00:09
#    ----------- --------------------------- 127.9/438.0 MB 37.5 MB/s eta 0:00:09
#    ------------ -------------------------- 137.6/438.0 MB 38.2 MB/s eta 0:00:08
#    ------------- ------------------------- 148.1/438.0 MB 38.6 MB/s eta 0:00:08
#    ------------- ------------------------- 156.2/438.0 MB 39.0 MB/s eta 0:00:08
#    -------------- ------------------------ 165.4/438.0 MB 38.7 MB/s eta 0:00:08
#    --------------- ----------------------- 174.9/438.0 MB 38.9 MB/s eta 0:00:07
kB)
# Downloading cachetools-6.2.1-py3-none-any.whl (11 kB)
# Downloading google_auth_oauthlib-0.4.6-py2.py3-none-any.whl (18 kB)
# Using cached requests-2.32.5-py3-none-any.whl (64 kB)
# Downloading charset_normalizer-3.4.4-cp310-cp310-win_amd64.whl (107 kB)
# Downloading idna-3.11-py3-none-any.whl (71 kB)
# Downloading rsa-4.9.1-py3-none-any.whl (34 kB)
# Downloading tensorboard_data_server-0.6.1-py3-none-any.whl (2.4 kB)
# Using cached urllib3-2.5.0-py3-none-any.whl (129 kB)
# Downloading pip-25.3-py3-none-any.whl (1.8 MB)
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 1.8/1.8 MB 47.4 MB/s  0:00:00
# Downloading absl_py-2.3.1-py3-none-any.whl (135 kB)
# Downloading astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Downloading certifi-2025.10.5-py3-none-any.whl (163 kB)
# Downloading flatbuffers-25.9.23-py2.py3-none-any.whl (30 kB)
# Downloading gast-0.6.0-py3-none-any.whl (21 kB)
# Downloading google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Downloading h5py-3.15.1-cp310-cp310-win_amd64.whl (2.9 MB)
#    ---------------------------------------- 0.0/2.9 MB ? eta -:--:--
#    ---------------------------------------- 2.9/2.9 MB 55.6 MB/s  0:00:00
# Downloading Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
# Downloading libclang-18.1.1-py2.py3-none-win_amd64.whl (26.4 MB)
#    ---------------------------------------- 0.0/26.4 MB ? eta -:--:--
#    --------------- ------------------------ 10.2/26.4 MB 49.1 MB/s eta 0:00:01
#    ------------------------------- -------- 21.0/26.4 MB 51.0 MB/s eta 0:00:01
#    ---------------------------------------- 26.4/26.4 MB 42.9 MB/s  0:00:00
# Downloading markdown-3.9-py3-none-any.whl (107 kB)
# Downloading numpy-2.2.6-cp310-cp310-win_amd64.whl (12.9 MB)
#    ---------------------------------------- 0.0/12.9 MB ? eta -:--:--
#    ------------------------------- -------- 10.2/12.9 MB 49.1 MB/s eta 0:00:01
#    ---------------------------------------- 12.9/12.9 MB 45.0 MB/s  0:00:00
# Downloading opt_einsum-3.4.0-py3-none-any.whl (71 kB)
# Downloading protobuf-6.33.0-cp310-abi3-win_amd64.whl (436 kB)
# Downloading pyasn1-0.6.1-py3-none-any.whl (83 kB)
# Downloading pyasn1_modules-0.4.2-py3-none-any.whl (181 kB)
# Downloading requests_oauthlib-2.0.0-py2.py3-none-any.whl (24 kB)
# Downloading oauthlib-3.3.1-py3-none-any.whl (160 kB)
# Downloading tensorboard_plugin_wit-1.8.1-py3-none-any.whl (781 kB)
#    ---------------------------------------- 0.0/781.3 kB ? eta -:--:--
#    ---------------------------------------- 781.3/781.3 kB 34.6 MB/s  0:00:00
# Downloading tensorflow_io_gcs_filesystem-0.31.0-cp310-cp310-win_amd64.whl (1.5 MB)
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    ---------------------------------------- 1.5/1.5 MB 39.5 MB/s  0:00:00
# Downloading termcolor-3.2.0-py3-none-any.whl (7.7 kB)
# Downloading werkzeug-3.1.3-py3-none-any.whl (224 kB)
# Downloading markupsafe-3.0.3-cp310-cp310-win_amd64.whl (15 kB)
# Downloading wrapt-2.0.0-cp310-cp310-win_amd64.whl (60 kB)
# Installing collected packages: tf-estimator-nightly, tensorboard-plugin-wit, libclang, keras, flatbuffers, wrapt, urllib3, termcolor, tensorflow-io-gcs-filesystem, tensorboard-data-server, pyasn1, protobuf, pip, opt-einsum, oauthlib, numpy, MarkupSafe, markdown, idna, grpcio, google-pasta, gast, charset_normalizer, certifi, cachetools, astunparse, absl-py, werkzeug, rsa, requests, pyasn1-modules, keras-preprocessing, h5py, requests-oauthlib, google-auth, google-auth-oauthlib, tensorboard, tensorflow
#
#    ----------------------------------------  0/38 [tf-estimator-nightly]
#    ----------------------------------------  0/38 [tf-estimator-nightly]
#    ----------------------------------------  0/38 [tf-estimator-nightly]
#    ----------------------------------------  0/38 [tf-estimator-nightly]
#    ----------------------------------------  0/38 [tf-estimator-nightly]
#    ----------------------------------------  0/38 [tf-estimator-nightly]
#    ----------------------------------------  0/38 [tf-estimator-nightly]
#    ----------------------------------------  0/38 [tf-estimator-nightly]
#    ----------------------------------------  0/38 [tf-estimator-nightly]
#    ----------------------------------------  0/38 [tf-estimator-nightly]
#    ----------------------------------------  0/38 [tf-estimator-nightly]
#    ----------------------------------------  0/38 [tf-estimator-nightly]
#    ----------------------------------------  0/38 [tf-estimator-nightly]
#    - --------------------------------------  1/38 [tensorboard-plugin-wit]
#    - --------------------------------------  1/38 [tensorboard-plugin-wit]
#    - --------------------------------------  1/38 [tensorboard-plugin-wit]
#    - --------------------------------------  1/38 [tensorboard-plugin-wit]
#    - --------------------------------------  1/38 [tensorboard-plugin-wit]
#    -- -------------------------------------  2/38 [libclang]
#    -- -------------------------------------  2/38 [libclang]
#    -- -------------------------------------  2/38 [libclang]
#    --- ------------------------------------  3/38 [keras]
#    --- ------------------------------------  3/38 [keras]
#    --- ------------------------------------  3/38 [keras]
#    --- ------------------------------------  3/38 [keras]
#    --- ------------------------------------  3/38 [keras]
#    --- ------------------------------------  3/38 [keras]
#    --- ------------------------------------  3/38 [keras]
#    --- ------------------------------------  3/38 [keras]
#    --- ------------------------------------  3/38 [keras]
#    --- ------------------------------------  3/38 [keras]
#    --- ------------------------------------  3/38 [keras]
#    --- ------------------------------------  3/38 [keras]
#    --- ------------------------------------  3/38 [keras]
#    --- ------------------------------------  3/38 [keras]
#    --- ------------------------------------  3/38 [keras]
#    --- ------------------------------------  3/38 [keras]
#    --- ------------------------------------  3/38 [keras]
#    --- ------------------------------------  3/38 [keras]
#    --- ------------------------------------  3/38 [keras]
#    --- ------------------------------------  3/38 [keras]
#    --- ------------------------------------  3/38 [keras]
#    --- ------------------------------------  3/38 [keras]
#    --- ------------------------------------  3/38 [keras]
#    --- ------------------------------------  3/38 [keras]
#    --- ------------------------------------  3/38 [keras]
#    --- ------------------------------------  3/38 [keras]
#    --- ------------------------------------  3/38 [keras]
#    --- ------------------------------------  3/38 [keras]
#    --- ------------------------------------  3/38 [keras]
#    --- ------------------------------------  3/38 [keras]
#    --- ------------------------------------  3/38 [keras]
#    --- ------------------------------------  3/38 [keras]
#    --- ------------------------------------  3/38 [keras]
#    --- ------------------------------------  3/38 [keras]
#    --- ------------------------------------  3/38 [keras]
#    --- ------------------------------------  3/38 [keras]
#    --- ------------------------------------  3/38 [keras]
#    --- ------------------------------------  3/38 [keras]
#    --- ------------------------------------  3/38 [keras]
#    --- ------------------------------------  3/38 [keras]
#    --- ------------------------------------  3/38 [keras]
#    --- ------------------------------------  3/38 [keras]
#    --- ------------------------------------  3/38 [keras]
#    --- ------------------------------------  3/38 [keras]
#    --- ------------------------------------  3/38 [keras]
#    --- ------------------------------------  3/38 [keras]
#    --- ------------------------------------  3/38 [keras]
#    --- ------------------------------------  3/38 [keras]
#    --- ------------------------------------  3/38 [keras]
#    --- ------------------------------------  3/38 [keras]
#    --- ------------------------------------  3/38 [keras]
#    --- ------------------------------------  3/38 [keras]
#    --- ------------------------------------  3/38 [keras]
#    --- ------------------------------------  3/38 [keras]
#    --- ------------------------------------  3/38 [keras]
#    --- ------------------------------------  3/38 [keras]
#    --- ------------------------------------  3/38 [keras]
#    --- ------------------------------------  3/38 [keras]
#    --- ------------------------------------  3/38 [keras]
#    --- ------------------------------------  3/38 [keras]
#    --- ------------------------------------  3/38 [keras]
#    --- ------------------------------------  3/38 [keras]
#    ---- -----------------------------------  4/38 [flatbuffers]
#    ----- ----------------------------------  5/38 [wrapt]
#    ------ ---------------------------------  6/38 [urllib3]
#    ------ ---------------------------------  6/38 [urllib3]
#    ------ ---------------------------------  6/38 [urllib3]
#    ------ ---------------------------------  6/38 [urllib3]
#    ------ ---------------------------------  6/38 [urllib3]
#    -------- ------------------------------  8/38 [tensorflow-io-gcs-filesystem]
#    ---------- ----------------------------- 10/38 [pyasn1]
#    ---------- ----------------------------- 10/38 [pyasn1]
#    ---------- ----------------------------- 10/38 [pyasn1]
#    ----------- ---------------------------- 11/38 [protobuf]
#    ----------- ---------------------------- 11/38 [protobuf]
#    ----------- ---------------------------- 11/38 [protobuf]
#    ----------- ---------------------------- 11/38 [protobuf]
#    ----------- ---------------------------- 11/38 [protobuf]
#    ----------- ---------------------------- 11/38 [protobuf]
#    ----------- ---------------------------- 11/38 [protobuf]
#    ----------- ---------------------------- 11/38 [protobuf]
#   Attempting uninstall: pip
#    ----------- ---------------------------- 11/38 [protobuf]
#     Found existing installation: pip 25.2
#    ----------- ---------------------------- 11/38 [protobuf]
#    ------------ --------------------------- 12/38 [pip]
#     Uninstalling pip-25.2:
#    ------------ --------------------------- 12/38 [pip]
#       Successfully uninstalled pip-25.2
#    ------------ --------------------------- 12/38 [pip]
#    ------------ --------------------------- 12/38 [pip]
#    ------------ --------------------------- 12/38 [pip]
#    ------------ --------------------------- 12/38 [pip]
#    ------------ --------------------------- 12/38 [pip]
#    ------------ --------------------------- 12/38 [pip]
#    ------------ --------------------------- 12/38 [pip]
#    ------------ --------------------------- 12/38 [pip]
#    ------------ --------------------------- 12/38 [pip]
#    ------------ --------------------------- 12/38 [pip]
#    ------------ --------------------------- 12/38 [pip]
#    ------------ --------------------------- 12/38 [pip]
#    ------------ --------------------------- 12/38 [pip]
#    ------------ --------------------------- 12/38 [pip]
#    ------------ --------------------------- 12/38 [pip]
#    ------------ --------------------------- 12/38 [pip]
#    ------------ --------------------------- 12/38 [pip]
#    ------------ --------------------------- 12/38 [pip]
#    ------------ --------------------------- 12/38 [pip]
#    ------------ --------------------------- 12/38 [pip]
#    ------------ --------------------------- 12/38 [pip]
#    ------------ --------------------------- 12/38 [pip]
#    ------------ --------------------------- 12/38 [pip]
#    ------------ --------------------------- 12/38 [pip]
#    ------------ --------------------------- 12/38 [pip]
#    ------------ --------------------------- 12/38 [pip]
#    ------------ --------------------------- 12/38 [pip]
#    ------------ --------------------------- 12/38 [pip]
#    ------------ --------------------------- 12/38 [pip]
#    ------------ --------------------------- 12/38 [pip]
#    ------------ --------------------------- 12/38 [pip]
#    ------------ --------------------------- 12/38 [pip]
#    ------------ --------------------------- 12/38 [pip]
#    ------------ --------------------------- 12/38 [pip]
#    ------------ --------------------------- 12/38 [pip]
#    ------------ --------------------------- 12/38 [pip]
#    ------------ --------------------------- 12/38 [pip]
#    ------------ --------------------------- 12/38 [pip]
#    ------------ --------------------------- 12/38 [pip]
#    ------------ --------------------------- 12/38 [pip]
#    ------------ --------------------------- 12/38 [pip]
#    ------------ --------------------------- 12/38 [pip]
#    ------------ --------------------------- 12/38 [pip]
#    ------------ --------------------------- 12/38 [pip]
#    ------------ --------------------------- 12/38 [pip]
#    ------------ --------------------------- 12/38 [pip]
#    ------------ --------------------------- 12/38 [pip]
#    ------------- -------------------------- 13/38 [opt-einsum]
#    ------------- -------------------------- 13/38 [opt-einsum]
#    ------------- -------------------------- 13/38 [opt-einsum]
#    ------------- -------------------------- 13/38 [opt-einsum]
#    -------------- ------------------------- 14/38 [oauthlib]
#    -------------- ------------------------- 14/38 [oauthlib]
#    -------------- ------------------------- 14/38 [oauthlib]
#    -------------- ------------------------- 14/38 [oauthlib]
#    -------------- ------------------------- 14/38 [oauthlib]
#    -------------- ------------------------- 14/38 [oauthlib]
#    -------------- ------------------------- 14/38 [oauthlib]
#    -------------- ------------------------- 14/38 [oauthlib]
#    -------------- ------------------------- 14/38 [oauthlib]
#    --------------- ------------------------ 15/38 [numpy]
#    --------------- ------------------------ 15/38 [numpy]
#    --------------- ------------------------ 15/38 [numpy]
#    --------------- ------------------------ 15/38 [numpy]
#    --------------- ------------------------ 15/38 [numpy]
#    --------------- ------------------------ 15/38 [numpy]
#    --------------- ------------------------ 15/38 [numpy]
#    --------------- ------------------------ 15/38 [numpy]
#    --------------- ------------------------ 15/38 [numpy]
#    --------------- ------------------------ 15/38 [numpy]
#    --------------- ------------------------ 15/38 [numpy]
#    --------------- ------------------------ 15/38 [numpy]
#    --------------- ------------------------ 15/38 [numpy]
#    --------------- ------------------------ 15/38 [numpy]
#    --------------- ------------------------ 15/38 [numpy]
#    --------------- ------------------------ 15/38 [numpy]
#    --------------- ------------------------ 15/38 [numpy]
#    --------------- ------------------------ 15/38 [numpy]
#    --------------- ------------------------ 15/38 [numpy]
#    --------------- ------------------------ 15/38 [numpy]
#    --------------- ------------------------ 15/38 [numpy]
#    --------------- ------------------------ 15/38 [numpy]
#    --------------- ------------------------ 15/38 [numpy]
#    --------------- ------------------------ 15/38 [numpy]
#    --------------- ------------------------ 15/38 [numpy]
#    --------------- ------------------------ 15/38 [numpy]
#    --------------- ------------------------ 15/38 [numpy]
#    --------------- ------------------------ 15/38 [numpy]
#    --------------- ------------------------ 15/38 [numpy]
#    --------------- ------------------------ 15/38 [numpy]
#    --------------- ------------------------ 15/38 [numpy]
#    --------------- ------------------------ 15/38 [numpy]
#    --------------- ------------------------ 15/38 [numpy]
#    --------------- ------------------------ 15/38 [numpy]
#    --------------- ------------------------ 15/38 [numpy]
#    --------------- ------------------------ 15/38 [numpy]
#    --------------- ------------------------ 15/38 [numpy]
#    --------------- ------------------------ 15/38 [numpy]
#    --------------- ------------------------ 15/38 [numpy]
#    --------------- ------------------------ 15/38 [numpy]
#    --------------- ------------------------ 15/38 [numpy]
#    --------------- ------------------------ 15/38 [numpy]
#    --------------- ------------------------ 15/38 [numpy]
#    --------------- ------------------------ 15/38 [numpy]
#    --------------- ------------------------ 15/38 [numpy]
#    --------------- ------------------------ 15/38 [numpy]
#    --------------- ------------------------ 15/38 [numpy]
#    --------------- ------------------------ 15/38 [numpy]
#    --------------- ------------------------ 15/38 [numpy]
#    --------------- ------------------------ 15/38 [numpy]
#    --------------- ------------------------ 15/38 [numpy]
#    --------------- ------------------------ 15/38 [numpy]
#    --------------- ------------------------ 15/38 [numpy]
#    --------------- ------------------------ 15/38 [numpy]
#    --------------- ------------------------ 15/38 [numpy]
#    --------------- ------------------------ 15/38 [numpy]
#    --------------- ------------------------ 15/38 [numpy]
#    --------------- ------------------------ 15/38 [numpy]
#    --------------- ------------------------ 15/38 [numpy]
#    --------------- ------------------------ 15/38 [numpy]
#    --------------- ------------------------ 15/38 [numpy]
#    --------------- ------------------------ 15/38 [numpy]
#    --------------- ------------------------ 15/38 [numpy]
#    --------------- ------------------------ 15/38 [numpy]
#    --------------- ------------------------ 15/38 [numpy]
#    --------------- ------------------------ 15/38 [numpy]
#    --------------- ------------------------ 15/38 [numpy]
#    --------------- ------------------------ 15/38 [numpy]
#    --------------- ------------------------ 15/38 [numpy]
#    --------------- ------------------------ 15/38 [numpy]
#    ----------------- ---------------------- 17/38 [markdown]
#    ----------------- ---------------------- 17/38 [markdown]
#    ----------------- ---------------------- 17/38 [markdown]
#    ----------------- ---------------------- 17/38 [markdown]
#    ----------------- ---------------------- 17/38 [markdown]
#    ----------------- ---------------------- 17/38 [markdown]
#    ------------------ --------------------- 18/38 [idna]
#    ------------------ --------------------- 18/38 [idna]
#    -------------------- ------------------- 19/38 [grpcio]
#    -------------------- ------------------- 19/38 [grpcio]
#    -------------------- ------------------- 19/38 [grpcio]
#    -------------------- ------------------- 19/38 [grpcio]
#    -------------------- ------------------- 19/38 [grpcio]
#    -------------------- ------------------- 19/38 [grpcio]
#    --------------------- ------------------ 20/38 [google-pasta]
#    --------------------- ------------------ 20/38 [google-pasta]
#    --------------------- ------------------ 20/38 [google-pasta]
#    ---------------------- ----------------- 21/38 [gast]
#    ----------------------- ---------------- 22/38 [charset_normalizer]
#    ----------------------- ---------------- 22/38 [charset_normalizer]
#    ----------------------- ---------------- 22/38 [charset_normalizer]
#    ------------------------ --------------- 23/38 [certifi]
#    -------------------------- ------------- 25/38 [astunparse]
#    --------------------------- ------------ 26/38 [absl-py]
#    --------------------------- ------------ 26/38 [absl-py]
#    --------------------------- ------------ 26/38 [absl-py]
#    --------------------------- ------------ 26/38 [absl-py]
#    ---------------------------- ----------- 27/38 [werkzeug]
#    ---------------------------- ----------- 27/38 [werkzeug]
#    ---------------------------- ----------- 27/38 [werkzeug]
#    ---------------------------- ----------- 27/38 [werkzeug]
#    ---------------------------- ----------- 27/38 [werkzeug]
#    ---------------------------- ----------- 27/38 [werkzeug]
#    ---------------------------- ----------- 27/38 [werkzeug]
#    ---------------------------- ----------- 27/38 [werkzeug]
#    ---------------------------- ----------- 27/38 [werkzeug]
#    ---------------------------- ----------- 27/38 [werkzeug]
#    ---------------------------- ----------- 27/38 [werkzeug]
#    ---------------------------- ----------- 27/38 [werkzeug]
#    ----------------------------- ---------- 28/38 [rsa]
#    ----------------------------- ---------- 28/38 [rsa]
#    ----------------------------- ---------- 28/38 [rsa]
#    ----------------------------- ---------- 28/38 [rsa]
#    ----------------------------- ---------- 28/38 [rsa]
#    ----------------------------- ---------- 28/38 [rsa]
#    ----------------------------- ---------- 28/38 [rsa]
#    ------------------------------ --------- 29/38 [requests]
#    ------------------------------ --------- 29/38 [requests]
#    ------------------------------ --------- 29/38 [requests]
#    ------------------------------- -------- 30/38 [pyasn1-modules]
#    ------------------------------- -------- 30/38 [pyasn1-modules]
#    ------------------------------- -------- 30/38 [pyasn1-modules]
#    ------------------------------- -------- 30/38 [pyasn1-modules]
#    ------------------------------- -------- 30/38 [pyasn1-modules]
#    ------------------------------- -------- 30/38 [pyasn1-modules]
#    ------------------------------- -------- 30/38 [pyasn1-modules]
#    ------------------------------- -------- 30/38 [pyasn1-modules]
#    ------------------------------- -------- 30/38 [pyasn1-modules]
#    ------------------------------- -------- 30/38 [pyasn1-modules]
#    ------------------------------- -------- 30/38 [pyasn1-modules]
#    ------------------------------- -------- 30/38 [pyasn1-modules]
#    ------------------------------- -------- 30/38 [pyasn1-modules]
#    ------------------------------- -------- 30/38 [pyasn1-modules]
#    ------------------------------- -------- 30/38 [pyasn1-modules]
#    ------------------------------- -------- 30/38 [pyasn1-modules]
#    ------------------------------- -------- 30/38 [pyasn1-modules]
#    -------------------------------- ------- 31/38 [keras-preprocessing]
#    -------------------------------- ------- 31/38 [keras-preprocessing]
#    --------------------------------- ------ 32/38 [h5py]
#    --------------------------------- ------ 32/38 [h5py]
#    --------------------------------- ------ 32/38 [h5py]
#    --------------------------------- ------ 32/38 [h5py]
#    --------------------------------- ------ 32/38 [h5py]
#    --------------------------------- ------ 32/38 [h5py]
#    --------------------------------- ------ 32/38 [h5py]
#    --------------------------------- ------ 32/38 [h5py]
#    ---------------------------------- ----- 33/38 [requests-oauthlib]
#    ----------------------------------- ---- 34/38 [google-auth]
#    ----------------------------------- ---- 34/38 [google-auth]
#    ----------------------------------- ---- 34/38 [google-auth]
#    ----------------------------------- ---- 34/38 [google-auth]
#    ----------------------------------- ---- 34/38 [google-auth]
#    ----------------------------------- ---- 34/38 [google-auth]
#    ----------------------------------- ---- 34/38 [google-auth]
#    ----------------------------------- ---- 34/38 [google-auth]
#    ----------------------------------- ---- 34/38 [google-auth]
#    ----------------------------------- ---- 34/38 [google-auth]
#    ------------------------------------ --- 35/38 [google-auth-oauthlib]
#    ------------------------------------ --- 35/38 [google-auth-oauthlib]
#    ------------------------------------- -- 36/38 [tensorboard]
#    ------------------------------------- -- 36/38 [tensorboard]
#    ------------------------------------- -- 36/38 [tensorboard]
#    ------------------------------------- -- 36/38 [tensorboard]
#    ------------------------------------- -- 36/38 [tensorboard]
#    ------------------------------------- -- 36/38 [tensorboard]
#    ------------------------------------- -- 36/38 [tensorboard]
#    ------------------------------------- -- 36/38 [tensorboard]
#    ------------------------------------- -- 36/38 [tensorboard]
#    ------------------------------------- -- 36/38 [tensorboard]
#    ------------------------------------- -- 36/38 [tensorboard]
#    ------------------------------------- -- 36/38 [tensorboard]
#    ------------------------------------- -- 36/38 [tensorboard]
#    ------------------------------------- -- 36/38 [tensorboard]
#    ------------------------------------- -- 36/38 [tensorboard]
#    ------------------------------------- -- 36/38 [tensorboard]
#    ------------------------------------- -- 36/38 [tensorboard]
#    ------------------------------------- -- 36/38 [tensorboard]
#    ------------------------------------- -- 36/38 [tensorboard]
#    ------------------------------------- -- 36/38 [tensorboard]
#    ------------------------------------- -- 36/38 [tensorboard]
#    ------------------------------------- -- 36/38 [tensorboard]
#    ------------------------------------- -- 36/38 [tensorboard]
#    ------------------------------------- -- 36/38 [tensorboard]
#    ------------------------------------- -- 36/38 [tensorboard]
#    ------------------------------------- -- 36/38 [tensorboard]
#    ------------------------------------- -- 36/38 [tensorboard]
#    ------------------------------------- -- 36/38 [tensorboard]
#    ------------------------------------- -- 36/38 [tensorboard]
#    ------------------------------------- -- 36/38 [tensorboard]
#    ------------------------------------- -- 36/38 [tensorboard]
#    ------------------------------------- -- 36/38 [tensorboard]
#    ------------------------------------- -- 36/38 [tensorboard]
#    ------------------------------------- -- 36/38 [tensorboard]
#    ------------------------------------- -- 36/38 [tensorboard]
#    ------------------------------------- -- 36/38 [tensorboard]
#    ------------------------------------- -- 36/38 [tensorboard]
#    ------------------------------------- -- 36/38 [tensorboard]
#    ------------------------------------- -- 36/38 [tensorboard]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    -------------------------------------- - 37/38 [tensorflow]
#    ---------------------------------------- 38/38 [tensorflow]
#
# Successfully installed MarkupSafe-3.0.3 absl-py-2.3.1 astunparse-1.6.3 cachetools-6.2.1 certifi-2025.10.5 charset_normalizer-3.4.4 flatbuffers-25.9.23 gast-0.6.0 google-auth-2.42.0 google-auth-oauthlib-0.4.6 google-pasta-0.2.0 grpcio-1.76.0 h5py-3.15.1 idna-3.11 keras-2.8.0 keras-preprocessing-1.1.2 libclang-18.1.1 markdown-3.9 numpy-2.2.6 oauthlib-3.3.1 opt-einsum-3.4.0 pip-25.3 protobuf-6.33.0 pyasn1-0.6.1 pyasn1-modules-0.4.2 requests-2.32.5 requests-oauthlib-2.0.0 rsa-4.9.1 tensorboard-2.8.0 tensorboard-data-server-0.6.1 tensorboard-plugin-wit-1.8.1 tensorflow-2.8.0 tensorflow-io-gcs-filesystem-0.31.0 termcolor-3.2.0 tf-estimator-nightly-2.8.0.dev2021122109 urllib3-2.5.0 werkzeug-3.1.3 wrapt-2.0.0
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The scripts pip.exe, pip3.10.exe and pip3.exe are installed in 'C:\Users\artembruh\.conda\envs\my_env\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts f2py.exe and numpy-config.exe are installed in 'C:\Users\artembruh\.conda\envs\my_env\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script markdown_py.exe is installed in 'C:\Users\artembruh\.conda\envs\my_env\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script normalizer.exe is installed in 'C:\Users\artembruh\.conda\envs\my_env\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts pyrsa-decrypt.exe, pyrsa-encrypt.exe, pyrsa-keygen.exe, pyrsa-priv2pub.exe, pyrsa-sign.exe and pyrsa-verify.exe are installed in 'C:\Users\artembruh\.conda\envs\my_env\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script google-oauthlib-tool.exe is installed in 'C:\Users\artembruh\.conda\envs\my_env\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script tensorboard.exe is installed in 'C:\Users\artembruh\.conda\envs\my_env\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts estimator_ckpt_converter.exe, import_pb_to_tensorboard.exe, saved_model_cli.exe, tensorboard.exe, tf_upgrade_v2.exe, tflite_convert.exe, toco.exe and toco_from_protos.exe are installed in 'C:\Users\artembruh\.conda\envs\my_env\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
pip install pillow
# Out:
# Collecting pillow
#   Downloading pillow-12.0.0-cp310-cp310-win_amd64.whl.metadata (9.0 kB)
# Downloading pillow-12.0.0-cp310-cp310-win_amd64.whl (7.0 MB)
#    ---------------------------------------- 0.0/7.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/7.0 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/7.0 MB 4.2 MB/s eta 0:00:02
#    ----- ---------------------------------- 1.0/7.0 MB 2.8 MB/s eta 0:00:03
#    ----------- ---------------------------- 2.1/7.0 MB 3.7 MB/s eta 0:00:02
#    ------------------- -------------------- 3.4/7.0 MB 4.0 MB/s eta 0:00:01
#    ---------------------- ----------------- 3.9/7.0 MB 4.0 MB/s eta 0:00:01
#    ----------------------------- ---------- 5.2/7.0 MB 4.4 MB/s eta 0:00:01
#    ------------------------------------- -- 6.6/7.0 MB 4.5 MB/s eta 0:00:01
#    ---------------------------------------- 7.0/7.0 MB 4.4 MB/s  0:00:01
# Installing collected packages: pillow
# Successfully installed pillow-12.0.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install protobuf==3.20.3
# Out:
# Collecting protobuf==3.20.3
#   Downloading protobuf-3.20.3-cp310-cp310-win_amd64.whl.metadata (698 bytes)
# Downloading protobuf-3.20.3-cp310-cp310-win_amd64.whl (904 kB)
#    ---------------------------------------- 0.0/904.0 kB ? eta -:--:--
#    ---------------------------------------- 0.0/904.0 kB ? eta -:--:--
#    ---------------------------------------- 904.0/904.0 kB 5.1 MB/s  0:00:00
# Installing collected packages: protobuf
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 6.33.0
#     Uninstalling protobuf-6.33.0:
#       Successfully uninstalled protobuf-6.33.0
# Successfully installed protobuf-3.20.3
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install numpy==1.24.3
# Out:
# Collecting numpy==1.24.3
#   Downloading numpy-1.24.3-cp310-cp310-win_amd64.whl.metadata (5.6 kB)
# Downloading numpy-1.24.3-cp310-cp310-win_amd64.whl (14.8 MB)
#    ---------------------------------------- 0.0/14.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/14.8 MB ? eta -:--:--
#    ---- ----------------------------------- 1.8/14.8 MB 7.7 MB/s eta 0:00:02
#    ---------------------- ----------------- 8.4/14.8 MB 22.6 MB/s eta 0:00:01
#    ------------------------------- -------- 11.5/14.8 MB 18.5 MB/s eta 0:00:01
#    ------------------------------------- -- 13.9/14.8 MB 17.1 MB/s eta 0:00:01
#    ---------------------------------------- 14.8/14.8 MB 15.8 MB/s  0:00:01
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.2.6
#     Uninstalling numpy-2.2.6:
#       Successfully uninstalled numpy-2.2.6
# Successfully installed numpy-1.24.3
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The script f2py.exe is installed in 'C:\Users\artembruh\.conda\envs\my_env\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
from keras.models import load_model  # TensorFlow is required for Keras to work
from PIL import Image, ImageOps  # Install pillow instead of PIL
import numpy as np
import glob
import tensorflow

# %% [markdown]
# Точность после обучения (из "Дополнительные сведения"):<br>
# хот-доги 96%<br>
# не хот-доги 94%

# %% [markdown]
# Тестирование в "Посмотреть" (webcam → файл):<br>
# 10 изображений из hot_dog_validation: 9/10 правильно (ошибка на размытом хот-доге — предсказано "не хот-дог" с 55% уверенности).<br>
# 10 изображений из not_hot_dog_validation: 8/10 правильно (ошибки на бургерах и сосисках — похожи визуально).<br>
# Вывод: Модель работает очень хорошо.<br>

# %%
# Disable scientific notation for clarity
np.set_printoptions(suppress=True)
# Load the model
model = load_model("1st_task/keras_Model.h5", compile=False)
# Load the labels
class_names = open("1st_task/labels.txt", "r", encoding="utf-8").readlines()

# %%
# Create the array of the right shape to feed into the keras model
# The 'length' or number of images you can put into the array is
# determined by the first position in the shape tuple, in this case 1
hot_dog_data = np.ndarray(shape=(1, 224, 224, 3), dtype=np.float32)
not_hot_dog_data = np.ndarray(shape=(1, 224, 224, 3), dtype=np.float32)
image_list = []

# %%
for filename in glob.glob('hot_dog_validation/*.jpg'):
    im=Image.open(filename)
    image_list.append(im)
# Replace this with the path to your image
image = Image.open(filename).convert("RGB")
# resizing the image to be at least 224x224 and then cropping from the center
size = (224, 224)
image = ImageOps.fit(image, size, Image.Resampling.LANCZOS)
# turn the image into a numpy array
image_array = np.asarray(image)
# Normalize the image
normalized_image_array = (image_array.astype(np.float32) / 127.5) - 1
# Load the image into the array
hot_dog_data[0] = normalized_image_array

# %%
for filename in glob.glob('not_hot_dog_validation/*.jpg'):
    im=Image.open(filename)
    image_list.append(im)
# Replace this with the path to your image
image = Image.open(filename).convert("RGB")
# resizing the image to be at least 224x224 and then cropping from the center
size = (224, 224)
image = ImageOps.fit(image, size, Image.Resampling.LANCZOS)
# turn the image into a numpy array
image_array = np.asarray(image)
# Normalize the image
normalized_image_array = (image_array.astype(np.float32) / 127.5) - 1
# Load the image into the array
not_hot_dog_data[0] = normalized_image_array

# %%
# Predicts the model
prediction = model.predict(hot_dog_data)
index = np.argmax(prediction)
class_name = class_names[index]
confidence_score = prediction[0][index]

# Print prediction and confidence score
print("Class:", class_name[2:], end="")
print("Confidence Score:", confidence_score)
# Out:
# Class: хот-доги
# Confidence Score: 0.9999939

# %%
# Predicts the model
prediction = model.predict(not_hot_dog_data)
index = np.argmax(prediction)
class_name = class_names[index]
confidence_score = prediction[0][index]

# Print prediction and confidence score
print("Class:", class_name[2:], end="")
print("Confidence Score:", confidence_score)
# Out:
# Class: не хот-доги
# Confidence Score: 0.999987

# %% [markdown]
# Точность после обучения (из "Дополнительные сведения"):<br>
# apple 100%<br>
# banana 100%<br>
# orange 100%<br>

# %%
# Disable scientific notation for clarity
np.set_printoptions(suppress=True)
# Load the model
model = load_model("2nd_task/keras_Model.h5", compile=False)
# Load the labels
class_names = open("2nd_task/labels.txt", "r", encoding="utf-8").readlines()

# %%
# Create the array of the right shape to feed into the keras model
# The 'length' or number of images you can put into the array is
# determined by the first position in the shape tuple, in this case 1
apple_data = np.ndarray(shape=(1, 224, 224, 3), dtype=np.float32)
banana_data = np.ndarray(shape=(1, 224, 224, 3), dtype=np.float32)
orange_data = np.ndarray(shape=(1, 224, 224, 3), dtype=np.float32)
image_list = []
