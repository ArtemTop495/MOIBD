# %%
import sys
print(sys.version)
# Out:
# 3.10.19 | packaged by Anaconda, Inc. | (main, Oct 21 2025, 16:41:31) [MSC v.1929 64 bit (AMD64)]

# %%
pip install --upgrade pip tensorflow==2.8.0
# Out:
# Requirement already satisfied: pip in c:\users\artembruh\anaconda3\envs\my_env\lib\site-packages (25.3)
# Requirement already satisfied: tensorflow==2.8.0 in c:\users\artembruh\anaconda3\envs\my_env\lib\site-packages (2.8.0)
# Requirement already satisfied: absl-py>=0.4.0 in c:\users\artembruh\anaconda3\envs\my_env\lib\site-packages (from tensorflow==2.8.0) (2.3.1)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\artembruh\anaconda3\envs\my_env\lib\site-packages (from tensorflow==2.8.0) (1.6.3)
# Requirement already satisfied: flatbuffers>=1.12 in c:\users\artembruh\anaconda3\envs\my_env\lib\site-packages (from tensorflow==2.8.0) (25.9.23)
# Requirement already satisfied: gast>=0.2.1 in c:\users\artembruh\anaconda3\envs\my_env\lib\site-packages (from tensorflow==2.8.0) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\artembruh\anaconda3\envs\my_env\lib\site-packages (from tensorflow==2.8.0) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\artembruh\anaconda3\envs\my_env\lib\site-packages (from tensorflow==2.8.0) (3.15.1)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in c:\users\artembruh\anaconda3\envs\my_env\lib\site-packages (from tensorflow==2.8.0) (1.1.2)
# Requirement already satisfied: libclang>=9.0.1 in c:\users\artembruh\anaconda3\envs\my_env\lib\site-packages (from tensorflow==2.8.0) (18.1.1)
# Requirement already satisfied: numpy>=1.20 in c:\users\artembruh\anaconda3\envs\my_env\lib\site-packages (from tensorflow==2.8.0) (1.24.3)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\artembruh\anaconda3\envs\my_env\lib\site-packages (from tensorflow==2.8.0) (3.4.0)
# Requirement already satisfied: protobuf>=3.9.2 in c:\users\artembruh\anaconda3\envs\my_env\lib\site-packages (from tensorflow==2.8.0) (3.20.3)
# Requirement already satisfied: setuptools in c:\users\artembruh\anaconda3\envs\my_env\lib\site-packages (from tensorflow==2.8.0) (80.9.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\artembruh\anaconda3\envs\my_env\lib\site-packages (from tensorflow==2.8.0) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\artembruh\anaconda3\envs\my_env\lib\site-packages (from tensorflow==2.8.0) (3.2.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\artembruh\anaconda3\envs\my_env\lib\site-packages (from tensorflow==2.8.0) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\artembruh\anaconda3\envs\my_env\lib\site-packages (from tensorflow==2.8.0) (2.0.0)
# Requirement already satisfied: tensorboard<2.9,>=2.8 in c:\users\artembruh\anaconda3\envs\my_env\lib\site-packages (from tensorflow==2.8.0) (2.8.0)
# Requirement already satisfied: tf-estimator-nightly==2.8.0.dev2021122109 in c:\users\artembruh\anaconda3\envs\my_env\lib\site-packages (from tensorflow==2.8.0) (2.8.0.dev2021122109)
# Requirement already satisfied: keras<2.9,>=2.8.0rc0 in c:\users\artembruh\anaconda3\envs\my_env\lib\site-packages (from tensorflow==2.8.0) (2.8.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\artembruh\anaconda3\envs\my_env\lib\site-packages (from tensorflow==2.8.0) (0.31.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\artembruh\anaconda3\envs\my_env\lib\site-packages (from tensorflow==2.8.0) (1.76.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\artembruh\anaconda3\envs\my_env\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8.0) (2.41.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\artembruh\anaconda3\envs\my_env\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8.0) (0.4.6)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\artembruh\anaconda3\envs\my_env\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8.0) (3.9)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\artembruh\anaconda3\envs\my_env\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8.0) (2.32.5)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\artembruh\anaconda3\envs\my_env\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8.0) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\artembruh\anaconda3\envs\my_env\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8.0) (1.8.1)
# Requirement already satisfied: werkzeug>=0.11.15 in c:\users\artembruh\anaconda3\envs\my_env\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8.0) (3.1.3)
# Requirement already satisfied: wheel>=0.26 in c:\users\artembruh\anaconda3\envs\my_env\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8.0) (0.45.1)
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in c:\users\artembruh\anaconda3\envs\my_env\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow==2.8.0) (6.2.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\artembruh\anaconda3\envs\my_env\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow==2.8.0) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\artembruh\anaconda3\envs\my_env\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow==2.8.0) (4.9.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\artembruh\anaconda3\envs\my_env\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow==2.8.0) (2.0.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\artembruh\anaconda3\envs\my_env\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow==2.8.0) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\artembruh\anaconda3\envs\my_env\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow==2.8.0) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\artembruh\anaconda3\envs\my_env\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow==2.8.0) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\artembruh\anaconda3\envs\my_env\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow==2.8.0) (2025.10.5)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\users\artembruh\anaconda3\envs\my_env\lib\site-packages (from rsa<5,>=3.1.4->google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow==2.8.0) (0.6.1)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\artembruh\anaconda3\envs\my_env\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow==2.8.0) (3.3.1)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\artembruh\anaconda3\envs\my_env\lib\site-packages (from werkzeug>=0.11.15->tensorboard<2.9,>=2.8->tensorflow==2.8.0) (3.0.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pillow
# Out:
# Requirement already satisfied: pillow in c:\users\artembruh\anaconda3\envs\my_env\lib\site-packages (12.0.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install protobuf==3.20.3
# Out:
# Requirement already satisfied: protobuf==3.20.3 in c:\users\artembruh\anaconda3\envs\my_env\lib\site-packages (3.20.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install numpy==1.24.3
# Out:
# Requirement already satisfied: numpy==1.24.3 in c:\users\artembruh\anaconda3\envs\my_env\lib\site-packages (1.24.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
from keras.models import load_model  # TensorFlow is required for Keras to work
from PIL import Image, ImageOps  # Install pillow instead of PIL
import numpy as np
import glob
import tensorflow

# %%
# Disable scientific notation for clarity
np.set_printoptions(suppress=True)
# Load the model
model = load_model("keras_Model.h5", compile=False)
# Load the labels
class_names = open("labels.txt", "r").readlines()

# %%
# Create the array of the right shape to feed into the keras model
# The 'length' or number of images you can put into the array is
# determined by the first position in the shape tuple, in this case 1
hot_dog_data = np.ndarray(shape=(1, 224, 224, 3), dtype=np.float32)
not_hot_dog_data = np.ndarray(shape=(1, 224, 224, 3), dtype=np.float32)
image_list = []

# %%
for filename in glob.glob('hot_dog_validation/*.jpg'):
    im=Image.open(filename)
    image_list.append(im)
# Replace this with the path to your image
image = Image.open(filename).convert("RGB")
# resizing the image to be at least 224x224 and then cropping from the center
size = (224, 224)
image = ImageOps.fit(image, size, Image.Resampling.LANCZOS)
# turn the image into a numpy array
image_array = np.asarray(image)
# Normalize the image
normalized_image_array = (image_array.astype(np.float32) / 127.5) - 1
# Load the image into the array
hot_dog_data[0] = normalized_image_array

# %%
for filename in glob.glob('not_hot_dog_validation/*.jpg'):
    im=Image.open(filename)
    image_list.append(im)
# Replace this with the path to your image
image = Image.open(filename).convert("RGB")
# resizing the image to be at least 224x224 and then cropping from the center
size = (224, 224)
image = ImageOps.fit(image, size, Image.Resampling.LANCZOS)
# turn the image into a numpy array
image_array = np.asarray(image)
# Normalize the image
normalized_image_array = (image_array.astype(np.float32) / 127.5) - 1
# Load the image into the array
not_hot_dog_data[0] = normalized_image_array

# %%
# Predicts the model
prediction = model.predict(hot_dog_data)
index = np.argmax(prediction)
class_name = class_names[index]
confidence_score = prediction[0][index]

# Print prediction and confidence score
print("Class:", class_name[2:], end="")
print("Confidence Score:", confidence_score)
# Out:
# Class: Ñ…Ð¾Ñ‚-Ð´Ð¾Ð³Ð¸
# Confidence Score: 0.9999939

# %%
# Predicts the model
prediction = model.predict(not_hot_dog_data)
index = np.argmax(prediction)
class_name = class_names[index]
confidence_score = prediction[0][index]

# Print prediction and confidence score
print("Class:", class_name[2:], end="")
print("Confidence Score:", confidence_score)
# Out:
# Class: Ð½Ðµ Ñ…Ð¾Ñ‚-Ð´Ð¾Ð³Ð¸
# Confidence Score: 0.999987
